# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    if labels[i] == 'POSITIVE':
        counter = positive_counts
    else:
        counter = negative_counts
    for word in reviews[i].split(' '):
        counter.update([word])
        total_counts.update([word])

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1100954),
#  ('the', 346657),
#  ('.', 319335),
#  ('and', 179445),
#  ('a', 167380),
#  ('of', 153714),
#  ('to', 133498),
#  ('is', 114494),
#  ('in', 100432),
#  ('br', 98470),
#  ('it', 96052),
#  ('i', 81491),
#  ('that', 71264),
#  ('this', 70160),
#  ('s', 67631),
#  ('as', 52618),
#  ('with', 46494),
#  ('for', 44832),
#  ('was', 43834),
#  ('film', 41874),
#  ('but', 41644),
#  ('movie', 38148),
#  ('his', 34454),
#  ('on', 34016),
#  ('you', 33362),
#  ('he', 32564),
#  ('are', 29614),
#  ('not', 28544),
#  ('t', 27441),
#  ('one', 27311),
#  ('have', 25174),
#  ('be', 24832),
#  ('by', 23994),
#  ('all', 23885),
#  ('who', 22929),
#  ('an', 22588),
#  ('at', 22470),
#  ('from', 21534),
#  ('her', 20948),
#  ('they', 19790),
#  ('has', 18372),
#  ('so', 18308),
#  ('like', 18076),
#  ('about', 16627),
#  ('very', 16610),
#  ('out', 16268),
#  ('there', 16114),
#  ('she', 15558),
#  ('what', 15475),
#  ('or', 15464),
#  ('good', 15440),
#  ('more', 15042),
#  ('when', 14913),
#  ('some', 14883),
#  ('if', 14570),
#  ('just', 14304),
#  ('can', 14003),
#  ('story', 13560),
#  ('time', 13031),
#  ('my', 12978),
#  ('great', 12838),
#  ('well', 12810),
#  ('up', 12642),
#  ('which', 12535),
#  ('their', 12216),
#  ('see', 12053),
#  ('also', 11100),
#  ('we', 11062),
#  ('really', 10952),
#  ('would', 10800),
#  ('will', 10436),
#  ('me', 10336),
#  ('had', 10296),
#  ('only', 10274),
#  ('him', 10036),
#  ('even', 9928),
#  ('most', 9728),
#  ('other', 9717),
#  ('were', 9564),
#  ('first', 9510),
#  ('than', 9473),
#  ('much', 9371),
#  ('its', 9244),
#  ('no', 9148),
#  ('into', 9088),
#  ('people', 8958),
#  ('best', 8638),
#  ('love', 8602),
#  ('get', 8544),
#  ('how', 8426),
#  ('life', 8399),
#  ('been', 8378),
#  ('because', 8158),
#  ('way', 8072),
#  ('do', 7882),
#  ('made', 7646),
#  ('films', 7626),
#  ('them', 7610),
#  ('after', 7600),
#  ('many', 7533),
#  ('two', 7466),
#  ('too', 7318),
#  ('think', 7311),
#  ('movies', 7172),
#  ('characters', 7120),
#  ('character', 7028),
#  ('don', 6936),
#  ('man', 6920),
#  ('show', 6864),
#  ('watch', 6848),
#  ('seen', 6828),
#  ('then', 6716),
#  ('little', 6682),
#  ('still', 6680),
#  ('make', 6606),
#  ('could', 6474),
#  ('never', 6452),
#  ('being', 6434),
#  ('where', 6346),
#  ('does', 6138),
#  ('over', 6034),
#  ('any', 6004),
#  ('while', 5798),
#  ('know', 5666),
#  ('did', 5580),
#  ('years', 5517),
#  ('here', 5481),
#  ('ever', 5468),
#  ('end', 5392),
#  ('these', 5388),
#  ('such', 5181),
#  ('real', 5136),
#  ('scene', 5134),
#  ('back', 5094),
#  ('those', 4970),
#  ('though', 4950),
#  ('off', 4926),
#  ('new', 4916),
#  ('your', 4907),
#  ('go', 4880),
#  ('acting', 4874),
#  ('plot', 4864),
#  ('world', 4858),
#  ('scenes', 4854),
#  ('say', 4828),
#  ('through', 4819),
#  ('makes', 4780),
#  ('better', 4762),
#  ('now', 4736),
#  ('work', 4692),
#  ('young', 4686),
#  ('old', 4622),
#  ('ve', 4614),
#  ('find', 4544),
#  ('both', 4496),
#  ('before', 4354),
#  ('us', 4324),
#  ('again', 4316),
#  ('series', 4306),
#  ('quite', 4286),
#  ('something', 4270),
#  ('cast', 4266),
#  ('should', 4242),
#  ('part', 4196),
#  ('always', 4176),
#  ('lot', 4174),
#  ('another', 4150),
#  ('actors', 4094),
#  ('director', 4080),
#  ('family', 4064),
#  ('between', 4032),
#  ('own', 4032),
#  ('m', 3997),
#  ('may', 3994),
#  ('same', 3945),
#  ('role', 3934),
#  ('watching', 3932),
#  ('every', 3908),
#  ('funny', 3906),
#  ('doesn', 3870),
#  ('performance', 3856),
#  ('few', 3836),
#  ('bad', 3814),
#  ('look', 3800),
#  ('re', 3768),
#  ('why', 3710),
#  ('things', 3698),
#  ('times', 3664),
#  ('big', 3630),
#  ('however', 3590),
#  ('actually', 3580),
#  ('action', 3578),
#  ('going', 3566),
#  ('bit', 3514),
#  ('comedy', 3485),
#  ('down', 3481),
#  ('music', 3476),
#  ('must', 3456),
#  ('take', 3418),
#  ('saw', 3385),
#  ('long', 3380),
#  ('right', 3377),
#  ('fun', 3372),
#  ('fact', 3368),
#  ('excellent', 3366),
#  ('around', 3348),
#  ('didn', 3344),
#  ('without', 3342),
#  ('thing', 3324),
#  ('thought', 3278),
#  ('got', 3270),
#  ('each', 3260),
#  ('day', 3228),
#  ('feel', 3194),
#  ('seems', 3192),
#  ('come', 3188),
#  ('done', 3172),
#  ('beautiful', 3160),
#  ('especially', 3144),
#  ('played', 3142),
#  ('almost', 3132),
#  ('want', 3124),
#  ('yet', 3112),
#  ('give', 3106),
#  ('pretty', 3098),
#  ('last', 3086),
#  ('since', 3038),
#  ('different', 3008),
#  ('although', 3002),
#  ('gets', 2980),
#  ('true', 2974),
#  ('interesting', 2962),
#  ('job', 2940),
#  ('enough', 2910),
#  ('our', 2908),
#  ('shows', 2894),
#  ('horror', 2882),
#  ('woman', 2878),
#  ('tv', 2800),
#  ('probably', 2796),
#  ('father', 2790),
#  ('original', 2786),
#  ('girl', 2780),
#  ('point', 2758),
#  ('plays', 2756),
#  ('wonderful', 2744),
#  ('far', 2717),
#  ('course', 2716),
#  ('john', 2700),
#  ('rather', 2680),
#  ('isn', 2657),
#  ('ll', 2652),
#  ('later', 2648),
#  ('dvd', 2648),
#  ('whole', 2621),
#  ('war', 2620),
#  ('d', 2614),
#  ('found', 2612),
#  ('away', 2612),
#  ('screen', 2610),
#  ('nothing', 2600),
#  ('year', 2594),
#  ('once', 2592),
#  ('hard', 2588),
#  ('together', 2560),
#  ('set', 2554),
#  ('am', 2554),
#  ('having', 2532),
#  ('making', 2530),
#  ('place', 2526),
#  ('might', 2520),
#  ('comes', 2520),
#  ('sure', 2506),
#  ('american', 2496),
#  ('play', 2490),
#  ('kind', 2488),
#  ('perfect', 2484),
#  ('takes', 2484),
#  ('performances', 2474),
#  ('himself', 2460),
#  ('worth', 2442),
#  ('everyone', 2442),
#  ('anyone', 2428),
#  ('actor', 2406),
#  ('three', 2402),
#  ('wife', 2392),
#  ('classic', 2385),
#  ('goes', 2372),
#  ('ending', 2356),
#  ('version', 2336),
#  ('star', 2298),
#  ('enjoy', 2292),
#  ('book', 2284),
#  ('nice', 2264),
#  ('everything', 2256),
#  ('during', 2248),
#  ('put', 2236),
#  ('seeing', 2222),
#  ('least', 2204),
#  ('house', 2200),
#  ('high', 2195),
#  ('watched', 2188),
#  ('loved', 2174),
#  ('men', 2174),
#  ('night', 2164),
#  ('anything', 2150),
#  ('believe', 2143),
#  ('guy', 2142),
#  ('top', 2126),
#  ('amazing', 2116),
#  ('hollywood', 2112),
#  ('looking', 2106),
#  ('main', 2088),
#  ('definitely', 2086),
#  ('gives', 2062),
#  ('home', 2058),
#  ('seem', 2056),
#  ('episode', 2047),
#  ('audience', 2040),
#  ('sense', 2040),
#  ('truly', 2034),
#  ('special', 2022),
#  ('second', 2018),
#  ('short', 2018),
#  ('fan', 2018),
#  ('mind', 2010),
#  ('human', 2002),
#  ('recommend', 1998),
#  ('full', 1992),
#  ('black', 1990),
#  ('help', 1982),
#  ('along', 1978),
#  ('trying', 1974),
#  ('small', 1972),
#  ('death', 1970),
#  ('friends', 1962),
#  ('remember', 1948),
#  ('often', 1940),
#  ('said', 1932),
#  ('favorite', 1924),
#  ('heart', 1918),
#  ('early', 1914),
#  ('left', 1912),
#  ('until', 1910),
#  ('script', 1908),
#  ('let', 1908),
#  ('maybe', 1874),
#  ('today', 1872),
#  ('live', 1868),
#  ('less', 1868),
#  ('moments', 1866),
#  ('others', 1858),
#  ('brilliant', 1852),
#  ('shot', 1850),
#  ('liked', 1846),
#  ('become', 1832),
#  ('won', 1830),
#  ('used', 1820),
#  ('style', 1814),
#  ('mother', 1790),
#  ('lives', 1788),
#  ('came', 1786),
#  ('stars', 1780),
#  ('cinema', 1778),
#  ('looks', 1770),
#  ('perhaps', 1768),
#  ('read', 1764),
#  ('enjoyed', 1758),
#  ('boy', 1750),
#  ('drama', 1746),
#  ('highly', 1742),
#  ('given', 1740),
#  ('playing', 1734),
#  ('use', 1728),
#  ('next', 1718),
#  ('women', 1716),
#  ('fine', 1714),
#  ('effects', 1712),
#  ('kids', 1708),
#  ('entertaining', 1706),
#  ('need', 1704),
#  ('line', 1701),
#  ('works', 1696),
#  ('someone', 1694),
#  ('mr', 1672),
#  ('simply', 1670),
#  ('picture', 1666),
#  ('children', 1666),
#  ('face', 1662),
#  ('keep', 1662),
#  ('friend', 1662),
#  ('dark', 1660),
#  ('overall', 1656),
#  ('certainly', 1656),
#  ('minutes', 1654),
#  ('wasn', 1648),
#  ('history', 1644),
#  ('finally', 1640),
#  ('couple', 1632),
#  ('against', 1630),
#  ('son', 1618),
#  ('understand', 1616),
#  ('lost', 1614),
#  ('michael', 1610),
#  ('else', 1602),
#  ('throughout', 1596),
#  ('fans', 1594),
#  ('city', 1584),
#  ('reason', 1578),
#  ('written', 1574),
#  ('production', 1574),
#  ('school', 1568),
#  ('several', 1568),
#  ('based', 1562),
#  ('rest', 1562),
#  ('try', 1560),
#  ('dead', 1552),
#  ('hope', 1550),
#  ('strong', 1536),
#  ('white', 1530),
#  ('tell', 1518),
#  ('itself', 1516),
#  ('half', 1506),
#  ('person', 1498),
#  ('sometimes', 1492),
#  ('past', 1488),
#  ('start', 1488),
#  ('genre', 1486),
#  ('beginning', 1478),
#  ('final', 1478),
#  ('town', 1476),
#  ('art', 1468),
#  ('humor', 1464),
#  ('game', 1464),
#  ('yes', 1462),
#  ('idea', 1462),
#  ('late', 1460),
#  ('becomes', 1458),
#  ('despite', 1458),
#  ('able', 1452),
#  ('case', 1452),
#  ('money', 1446),
#  ('child', 1442),
#  ('completely', 1442),
#  ('side', 1438),
#  ('camera', 1432),
#  ('getting', 1428),
#  ('instead', 1424),
#  ('soon', 1404),
#  ('under', 1400),
#  ('viewer', 1398),
#  ('age', 1395),
#  ('days', 1392),
#  ('stories', 1392),
#  ('felt', 1388),
#  ('simple', 1388),
#  ('roles', 1386),
#  ('video', 1376),
#  ('name', 1366),
#  ('either', 1366),
#  ('doing', 1354),
#  ('turns', 1348),
#  ('wants', 1342),
#  ('close', 1342),
#  ('title', 1338),
#  ('wrong', 1336),
#  ('went', 1332),
#  ('james', 1330),
#  ('evil', 1318),
#  ('budget', 1314),
#  ('episodes', 1314),
#  ('relationship', 1310),
#  ('fantastic', 1306),
#  ('piece', 1306),
#  ('david', 1302),
#  ('turn', 1296),
#  ('murder', 1292),
#  ('parts', 1290),
#  ('brother', 1288),
#  ('absolutely', 1286),
#  ('head', 1286),
#  ('experience', 1284),
#  ('eyes', 1282),
#  ('sex', 1276),
#  ('direction', 1274),
#  ('called', 1274),
#  ('directed', 1272),
#  ('lines', 1268),
#  ('behind', 1266),
#  ('sort', 1264),
#  ('actress', 1262),
#  ('lead', 1261),
#  ('oscar', 1256),
#  ('including', 1254),
#  ('example', 1254),
#  ('known', 1250),
#  ('musical', 1250),
#  ('chance', 1242),
#  ('score', 1240),
#  ('already', 1238),
#  ('feeling', 1238),
#  ('hit', 1238),
#  ('voice', 1230),
#  ('moment', 1224),
#  ('living', 1224),
#  ('low', 1220),
#  ('supporting', 1220),
#  ('ago', 1218),
#  ('themselves', 1216),
#  ('reality', 1211),
#  ('hilarious', 1210),
#  ('jack', 1208),
#  ('told', 1206),
#  ('hand', 1202),
#  ('quality', 1200),
#  ('moving', 1200),
#  ('dialogue', 1200),
#  ('song', 1198),
#  ('happy', 1198),
#  ('matter', 1196),
#  ('paul', 1196),
#  ('light', 1188),
#  ('future', 1186),
#  ('entire', 1184),
#  ('finds', 1182),
#  ('gave', 1178),
#  ('laugh', 1174),
#  ('released', 1172),
#  ('expect', 1169),
#  ('fight', 1162),
#  ('particularly', 1160),
#  ('cinematography', 1158),
#  ('police', 1158),
#  ('whose', 1156),
#  ('type', 1156),
#  ('sound', 1156),
#  ('view', 1146),
#  ('enjoyable', 1146),
#  ('number', 1144),
#  ('romantic', 1144),
#  ('husband', 1144),
#  ('daughter', 1144),
#  ('documentary', 1142),
#  ('self', 1140),
#  ('superb', 1138),
#  ('modern', 1138),
#  ('took', 1138),
#  ('robert', 1138),
#  ('mean', 1132),
#  ('shown', 1126),
#  ('coming', 1122),
#  ('important', 1120),
#  ('king', 1118),
#  ('leave', 1118),
#  ('change', 1116),
#  ('somewhat', 1110),
#  ('wanted', 1110),
#  ('tells', 1108),
#  ('events', 1104),
#  ('run', 1104),
#  ('career', 1104),
#  ('country', 1104),
#  ('heard', 1100),
#  ('season', 1100),
#  ('greatest', 1098),
#  ('girls', 1098),
#  ('etc', 1094),
#  ('care', 1092),
#  ('starts', 1090),
#  ('english', 1084),
#  ('killer', 1082),
#  ('tale', 1080),
#  ('guys', 1080),
#  ('totally', 1080),
#  ('animation', 1080),
#  ('usual', 1078),
#  ('miss', 1070),
#  ('opinion', 1070),
#  ('easy', 1062),
#  ('violence', 1062),
#  ('songs', 1060),
#  ('british', 1056),
#  ('says', 1052),
#  ('realistic', 1050),
#  ('writing', 1048),
#  ('writer', 1044),
#  ('act', 1044),
#  ('comic', 1042),
#  ('thriller', 1038),
#  ('television', 1034),
#  ('power', 1032),
#  ('ones', 1030),
#  ('kid', 1028),
#  ('york', 1026),
#  ('novel', 1026),
#  ('alone', 1024),
#  ('problem', 1024),
#  ('attention', 1018),
#  ('involved', 1016),
#  ('kill', 1014),
#  ('extremely', 1014),
#  ('seemed', 1012),
#  ('hero', 1010),
#  ('french', 1010),
#  ('rock', 1008),
#  ('stuff', 1002),
#  ('wish', 998),
#  ('begins', 996),
#  ('taken', 994),
#  ('sad', 994),
#  ('ways', 992),
#  ('richard', 990),
#  ('knows', 988),
#  ('atmosphere', 986),
#  ('similar', 982),
#  ('surprised', 982),
#  ('taking', 982),
#  ('car', 982),
#  ('george', 980),
#  ('perfectly', 980),
#  ('across', 978),
#  ('team', 978),
#  ('eye', 978),
#  ('sequence', 978),
#  ('room', 976),
#  ('due', 976),
#  ('among', 976),
#  ('serious', 976),
#  ('powerful', 976),
#  ('strange', 974),
#  ('order', 974),
#  ('cannot', 974),
#  ('b', 974),
#  ('beauty', 972),
#  ('famous', 970),
#  ('happened', 968),
#  ('tries', 968),
#  ('herself', 968),
#  ('myself', 968),
#  ('class', 966),
#  ('four', 964),
#  ('cool', 962),
#  ('release', 958),
#  ('anyway', 958),
#  ('theme', 958),
#  ('opening', 956),
#  ('entertainment', 954),
#  ('slow', 950),
#  ('ends', 950),
#  ('unique', 950),
#  ('exactly', 950),
#  ('easily', 948),
#  ('level', 948),
#  ('o', 948),
#  ('red', 948),
#  ('interest', 944),
#  ('happen', 942),
#  ('crime', 940),
#  ('viewing', 936),
#  ('sets', 934),
#  ('memorable', 934),
#  ('stop', 932),
#  ('group', 932),
#  ('problems', 926),
#  ('dance', 926),
#  ('working', 926),
#  ('sister', 926),
#  ('message', 926),
#  ('knew', 925),
#  ('mystery', 922),
#  ('nature', 922),
#  ('bring', 920),
#  ('believable', 918),
#  ('thinking', 918),
#  ('brought', 918),
#  ('mostly', 916),
#  ('disney', 914),
#  ('couldn', 914),
#  ('society', 912),
#  ('lady', 910),
#  ('within', 910),
#  ('blood', 908),
#  ('parents', 906),
#  ('upon', 906),
#  ('viewers', 906),
#  ('meets', 904),
#  ('form', 904),
#  ('peter', 904),
#  ('tom', 904),
#  ('usually', 904),
#  ('soundtrack', 904),
#  ('local', 900),
#  ('certain', 896),
#  ('follow', 896),
#  ('whether', 894),
#  ('possible', 892),
#  ('emotional', 890),
#  ('killed', 888),
#  ('above', 888),
#  ('de', 888),
#  ('god', 886),
#  ('middle', 886),
#  ('needs', 884),
#  ('happens', 884),
#  ('flick', 884),
#  ('masterpiece', 882),
#  ('period', 880),
#  ('major', 880),
#  ('named', 878),
#  ('haven', 878),
#  ('particular', 876),
#  ('th', 876),
#  ('earth', 874),
#  ('feature', 874),
#  ('stand', 872),
#  ('words', 870),
#  ('typical', 870),
#  ('elements', 866),
#  ('obviously', 866),
#  ('romance', 862),
#  ('jane', 860),
#  ('yourself', 854),
#  ('showing', 854),
#  ('brings', 852),
#  ('fantasy', 852),
#  ('guess', 846),
#  ('america', 846),
#  ('unfortunately', 844),
#  ('huge', 844),
#  ('indeed', 842),
#  ('running', 842),
#  ('talent', 840),
#  ('stage', 838),
#  ('started', 836),
#  ('leads', 834),
#  ('sweet', 834),
#  ('japanese', 834),
#  ('poor', 832),
#  ('deal', 832),
#  ('incredible', 826),
#  ('personal', 826),
#  ('fast', 824),
#  ('became', 820),
#  ('deep', 820),
#  ('hours', 818),
#  ('giving', 816),
#  ('nearly', 816),
#  ('dream', 816),
#  ('clearly', 814),
#  ('turned', 814),
#  ('obvious', 812),
#  ('near', 812),
#  ('cut', 810),
#  ('surprise', 810),
#  ('era', 808),
#  ('body', 808),
#  ('hour', 806),
#  ('female', 806),
#  ('five', 806),
#  ('note', 798),
#  ('learn', 796),
#  ('truth', 796),
#  ('except', 794),
#  ('feels', 794),
#  ('match', 794),
#  ('tony', 794),
#  ('filmed', 788),
#  ('clear', 788),
#  ('complete', 788),
#  ('street', 786),
#  ('eventually', 786),
#  ('keeps', 786),
#  ('older', 786),
#  ('lots', 786),
#  ('buy', 784),
#  ('william', 782),
#  ('stewart', 782),
#  ('fall', 780),
#  ('joe', 780),
#  ('meet', 780),
#  ('unlike', 778),
#  ('talking', 778),
#  ('shots', 778),
#  ('rating', 778),
#  ('difficult', 778),
#  ('dramatic', 776),
#  ('means', 776),
#  ('situation', 773),
#  ('wonder', 772),
#  ('present', 772),
#  ('appears', 772),
#  ('subject', 772),
#  ('comments', 770),
#  ('general', 766),
#  ('sequences', 766),
#  ('lee', 766),
#  ('points', 764),
#  ('earlier', 764),
#  ('gone', 758),
#  ('check', 758),
#  ('suspense', 756),
#  ('recommended', 756),
#  ('ten', 756),
#  ('third', 754),
#  ('business', 754),
#  ('talk', 750),
#  ('leaves', 750),
#  ('beyond', 750),
#  ('portrayal', 748),
#  ('beautifully', 746),
#  ('single', 744),
#  ('bill', 744),
#  ('plenty', 742),
#  ('word', 742),
#  ('whom', 740),
#  ('falls', 740),
#  ('scary', 738),
#  ('non', 738),
#  ('figure', 738),
#  ('battle', 738),
#  ('using', 736),
#  ('return', 736),
#  ('doubt', 734),
#  ('add', 734),
#  ('hear', 732),
#  ('solid', 732),
#  ('success', 732),
#  ('jokes', 730),
#  ('oh', 730),
#  ('touching', 730),
#  ('political', 730),
#  ('hell', 728),
#  ('awesome', 728),
#  ('boys', 728),
#  ('sexual', 724),
#  ('recently', 724),
#  ('dog', 724),
#  ('please', 722),
#  ('wouldn', 722),
#  ('straight', 722),
#  ('features', 722),
#  ('forget', 720),
#  ('setting', 720),
#  ('lack', 720),
#  ('married', 718),
#  ('mark', 718),
#  ('social', 714),
#  ('interested', 712),
#  ('adventure', 712),
#  ('actual', 710),
#  ('terrific', 710),
#  ('sees', 710),
#  ('brothers', 710),
#  ('move', 708),
#  ('call', 708),
#  ('various', 706),
#  ('theater', 706),
#  ('dr', 706),
#  ('animated', 704),
#  ('western', 702),
#  ('baby', 700),
#  ('space', 700),
#  ('leading', 696),
#  ('disappointed', 696),
#  ('portrayed', 692),
#  ('aren', 692),
#  ('screenplay', 690),
#  ('smith', 690),
#  ('towards', 688),
#  ('hate', 688),
#  ('noir', 686),
#  ('outstanding', 684),
#  ('decent', 684),
#  ('kelly', 684),
#  ('directors', 682),
#  ('journey', 682),
#  ('none', 680),
#  ('looked', 680),
#  ('effective', 680),
#  ('storyline', 678),
#  ('caught', 678),
#  ('sci', 678),
#  ('fi', 678),
#  ('cold', 678),
#  ('mary', 678),
#  ('rich', 676),
#  ('charming', 676),
#  ('popular', 674),
#  ('rare', 674),
#  ('manages', 674),
#  ('harry', 674),
#  ('spirit', 672),
#  ('appreciate', 670),
#  ('open', 670),
#  ('moves', 668),
#  ('basically', 668),
#  ('acted', 668),
#  ('inside', 666),
#  ('boring', 666),
#  ('century', 666),
#  ('mention', 666),
#  ('deserves', 666),
#  ('subtle', 666),
#  ('pace', 666),
#  ('familiar', 664),
#  ('background', 664),
#  ('ben', 662),
#  ('creepy', 660),
#  ('supposed', 660),
#  ('secret', 658),
#  ('die', 656),
#  ('jim', 656),
#  ('question', 654),
#  ('effect', 654),
#  ('natural', 654),
#  ('impressive', 652),
#  ('rate', 652),
#  ('language', 652),
#  ('saying', 650),
#  ('intelligent', 650),
#  ('telling', 648),
#  ('realize', 648),
#  ('material', 648),
#  ('scott', 648),
#  ('singing', 646),
#  ('dancing', 644),
#  ('visual', 642),
#  ('adult', 642),
#  ('imagine', 642),
#  ('kept', 640),
#  ('office', 640),
#  ('uses', 638),
#  ('pure', 636),
#  ('wait', 636),
#  ('stunning', 636),
#  ('review', 634),
#  ('previous', 634),
#  ('copy', 634),
#  ('seriously', 634),
#  ('reading', 632),
#  ('create', 632),
#  ('hot', 632),
#  ('created', 632),
#  ('magic', 632),
#  ('somehow', 632),
#  ('stay', 630),
#  ('attempt', 630),
#  ('escape', 630),
#  ('crazy', 630),
#  ('air', 630),
#  ('frank', 630),
#  ('hands', 628),
#  ('filled', 626),
#  ('expected', 624),
#  ('average', 624),
#  ('surprisingly', 624),
#  ('complex', 622),
#  ('quickly', 620),
#  ('successful', 620),
#  ('studio', 620),
#  ('plus', 618),
#  ('male', 618),
#  ('co', 614),
#  ('images', 612),
#  ('casting', 612),
#  ('following', 612),
#  ('minute', 612),
#  ('exciting', 612),
#  ('members', 610),
#  ('follows', 610),
#  ('themes', 610),
#  ('german', 610),
#  ('reasons', 610),
#  ('e', 610),
#  ('touch', 608),
#  ('edge', 608),
#  ('free', 608),
#  ('cute', 608),
#  ('genius', 608),
#  ('outside', 606),
#  ('reviews', 604),
#  ('admit', 604),
#  ('ok', 604),
#  ('younger', 604),
#  ('fighting', 602),
#  ('odd', 602),
#  ('master', 602),
#  ('recent', 600),
#  ('thanks', 600),
#  ('break', 600),
#  ('comment', 600),
#  ('apart', 598),
#  ('emotions', 596),
#  ('lovely', 596),
#  ('begin', 596),
#  ('doctor', 594),
#  ('party', 594),
#  ('italian', 594),
#  ('la', 592),
#  ('missed', 592),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1122929),
#  ('.', 335084),
#  ('the', 326782),
#  ('a', 158649),
#  ('and', 148771),
#  ('of', 138021),
#  ('to', 137949),
#  ('br', 105274),
#  ('is', 100168),
#  ('it', 96658),
#  ('i', 93760),
#  ('in', 87506),
#  ('this', 81840),
#  ('that', 75231),
#  ('s', 63094),
#  ('was', 52582),
#  ('movie', 49930),
#  ('for', 43855),
#  ('but', 43562),
#  ('with', 41759),
#  ('as', 41250),
#  ('t', 40722),
#  ('film', 38436),
#  ('you', 35099),
#  ('on', 34385),
#  ('not', 32708),
#  ('have', 30288),
#  ('are', 29246),
#  ('be', 29084),
#  ('he', 27712),
#  ('one', 26268),
#  ('they', 26022),
#  ('at', 24558),
#  ('his', 24294),
#  ('all', 24072),
#  ('so', 22926),
#  ('like', 22476),
#  ('there', 21550),
#  ('just', 21239),
#  ('by', 21100),
#  ('or', 20544),
#  ('an', 20533),
#  ('who', 19939),
#  ('from', 19463),
#  ('if', 19036),
#  ('about', 18122),
#  ('out', 17959),
#  ('what', 16844),
#  ('some', 16613),
#  ('no', 16287),
#  ('her', 15894),
#  ('even', 15375),
#  ('can', 15307),
#  ('has', 15209),
#  ('good', 14847),
#  ('bad', 14802),
#  ('would', 14073),
#  ('up', 13940),
#  ('only', 13562),
#  ('more', 13460),
#  ('when', 13452),
#  ('she', 12888),
#  ('really', 12524),
#  ('time', 12419),
#  ('had', 12284),
#  ('my', 12030),
#  ('were', 12002),
#  ('which', 11560),
#  ('very', 11528),
#  ('me', 11212),
#  ('see', 10904),
#  ('don', 10672),
#  ('we', 10656),
#  ('their', 10556),
#  ('do', 10472),
#  ('story', 10417),
#  ('than', 10367),
#  ('been', 10200),
#  ('much', 10156),
#  ('get', 10074),
#  ('because', 9932),
#  ('people', 9612),
#  ('then', 9522),
#  ('make', 9445),
#  ('how', 9376),
#  ('could', 9372),
#  ('any', 9316),
#  ('into', 9135),
#  ('made', 9082),
#  ('first', 8612),
#  ('other', 8610),
#  ('well', 8508),
#  ('too', 8349),
#  ('them', 8330),
#  ('plot', 8308),
#  ('movies', 8160),
#  ('acting', 8112),
#  ('will', 7986),
#  ('way', 7978),
#  ('most', 7838),
#  ('him', 7716),
#  ('after', 7676),
#  ('its', 7310),
#  ('think', 7287),
#  ('also', 7216),
#  ('characters', 7200),
#  ('off', 7136),
#  ('watch', 7100),
#  ('character', 7012),
#  ('did', 7012),
#  ('why', 6926),
#  ('being', 6786),
#  ('better', 6717),
#  ('know', 6668),
#  ('over', 6632),
#  ('seen', 6531),
#  ('ever', 6526),
#  ('never', 6518),
#  ('your', 6466),
#  ('where', 6438),
#  ('two', 6346),
#  ('little', 6192),
#  ('films', 6154),
#  ('here', 6054),
#  ('m', 6000),
#  ('nothing', 5980),
#  ('say', 5964),
#  ('end', 5908),
#  ('something', 5884),
#  ('should', 5841),
#  ('many', 5818),
#  ('does', 5742),
#  ('thing', 5732),
#  ('show', 5724),
#  ('ve', 5658),
#  ('scene', 5633),
#  ('scenes', 5570),
#  ('these', 5448),
#  ('go', 5434),
#  ('didn', 5292),
#  ('great', 5281),
#  ('watching', 5280),
#  ('re', 5240),
#  ('doesn', 5202),
#  ('through', 5120),
#  ('such', 5088),
#  ('man', 5033),
#  ('worst', 4960),
#  ('actually', 4898),
#  ('actors', 4874),
#  ('life', 4858),
#  ('back', 4848),
#  ('while', 4836),
#  ('director', 4810),
#  ('funny', 4672),
#  ('going', 4638),
#  ('still', 4566),
#  ('another', 4508),
#  ('look', 4494),
#  ('now', 4474),
#  ('old', 4430),
#  ('those', 4425),
#  ('real', 4340),
#  ('few', 4316),
#  ('love', 4304),
#  ('horror', 4300),
#  ('before', 4294),
#  ('want', 4282),
#  ('minutes', 4252),
#  ('pretty', 4230),
#  ('best', 4188),
#  ('though', 4182),
#  ('same', 4162),
#  ('script', 4148),
#  ('work', 4054),
#  ('every', 4050),
#  ('seems', 4046),
#  ('least', 4022),
#  ('enough', 3994),
#  ('down', 3976),
#  ('original', 3966),
#  ('guy', 3928),
#  ('got', 3904),
#  ('around', 3886),
#  ('part', 3884),
#  ('lot', 3784),
#  ('anything', 3748),
#  ('find', 3720),
#  ('new', 3708),
#  ('again', 3698),
#  ('isn', 3698),
#  ('point', 3690),
#  ('things', 3678),
#  ('fact', 3678),
#  ('give', 3646),
#  ('makes', 3628),
#  ('take', 3600),
#  ('thought', 3596),
#  ('d', 3540),
#  ('whole', 3537),
#  ('long', 3522),
#  ('years', 3518),
#  ('however', 3480),
#  ('gets', 3428),
#  ('making', 3391),
#  ('cast', 3388),
#  ('big', 3324),
#  ('might', 3317),
#  ('interesting', 3296),
#  ('money', 3276),
#  ('us', 3256),
#  ('right', 3250),
#  ('far', 3238),
#  ('quite', 3192),
#  ('without', 3190),
#  ('come', 3190),
#  ('almost', 3148),
#  ('ll', 3134),
#  ('action', 3132),
#  ('awful', 3114),
#  ('kind', 3078),
#  ('reason', 3068),
#  ('am', 3060),
#  ('looks', 3056),
#  ('must', 3044),
#  ('done', 3020),
#  ('comedy', 3009),
#  ('someone', 2980),
#  ('trying', 2972),
#  ('wasn', 2968),
#  ('poor', 2962),
#  ('boring', 2956),
#  ('instead', 2956),
#  ('saw', 2950),
#  ('away', 2938),
#  ('girl', 2926),
#  ('probably', 2888),
#  ('believe', 2868),
#  ('sure', 2866),
#  ('looking', 2860),
#  ('stupid', 2856),
#  ('anyone', 2836),
#  ('times', 2812),
#  ('maybe', 2808),
#  ('world', 2808),
#  ('rather', 2788),
#  ('terrible', 2782),
#  ('may', 2780),
#  ('last', 2780),
#  ('since', 2776),
#  ('let', 2770),
#  ('tv', 2764),
#  ('hard', 2748),
#  ('between', 2748),
#  ('waste', 2716),
#  ('woman', 2712),
#  ('feel', 2708),
#  ('effects', 2696),
#  ('half', 2682),
#  ('own', 2666),
#  ('young', 2634),
#  ('music', 2632),
#  ('idea', 2624),
#  ('sense', 2612),
#  ('bit', 2596),
#  ('having', 2560),
#  ('book', 2556),
#  ('found', 2534),
#  ('put', 2526),
#  ('series', 2526),
#  ('goes', 2512),
#  ('worse', 2498),
#  ('said', 2460),
#  ('comes', 2448),
#  ('role', 2444),
#  ('main', 2440),
#  ('else', 2398),
#  ('everything', 2394),
#  ('yet', 2392),
#  ('low', 2378),
#  ('screen', 2376),
#  ('supposed', 2372),
#  ('actor', 2370),
#  ('either', 2366),
#  ('budget', 2358),
#  ('ending', 2358),
#  ('audience', 2357),
#  ('set', 2354),
#  ('family', 2340),
#  ('left', 2338),
#  ('completely', 2336),
#  ('both', 2316),
#  ('wrong', 2310),
#  ('always', 2302),
#  ('course', 2296),
#  ('place', 2296),
#  ('seem', 2295),
#  ('watched', 2284),
#  ('day', 2264),
#  ('simply', 2260),
#  ('shot', 2252),
#  ('mean', 2234),
#  ('special', 2204),
#  ('dead', 2202),
#  ('three', 2188),
#  ('house', 2170),
#  ('oh', 2168),
#  ('night', 2166),
#  ('read', 2164),
#  ('less', 2134),
#  ('high', 2132),
#  ('year', 2128),
#  ('camera', 2122),
#  ('worth', 2114),
#  ('our', 2112),
#  ('try', 2102),
#  ('horrible', 2092),
#  ('sex', 2092),
#  ('video', 2086),
#  ('black', 2078),
#  ('although', 2072),
#  ('couldn', 2072),
#  ('once', 2066),
#  ('rest', 2044),
#  ('dvd', 2042),
#  ('line', 2036),
#  ('played', 2034),
#  ('fun', 2014),
#  ('during', 2012),
#  ('production', 2006),
#  ('everyone', 2004),
#  ('play', 1986),
#  ('mind', 1980),
#  ('version', 1978),
#  ('kids', 1978),
#  ('seeing', 1976),
#  ('american', 1960),
#  ('given', 1956),
#  ('used', 1938),
#  ('performance', 1936),
#  ('especially', 1926),
#  ('together', 1926),
#  ('tell', 1918),
#  ('women', 1916),
#  ('start', 1912),
#  ('need', 1910),
#  ('second', 1906),
#  ('takes', 1900),
#  ('each', 1900),
#  ('wife', 1888),
#  ('dialogue', 1885),
#  ('use', 1880),
#  ('problem', 1876),
#  ('star', 1868),
#  ('unfortunately', 1863),
#  ('himself', 1858),
#  ('doing', 1852),
#  ('death', 1844),
#  ('name', 1842),
#  ('lines', 1838),
#  ('killer', 1828),
#  ('getting', 1826),
#  ('help', 1810),
#  ('couple', 1804),
#  ('fan', 1804),
#  ('head', 1796),
#  ('crap', 1790),
#  ('guess', 1776),
#  ('piece', 1768),
#  ('nice', 1760),
#  ('different', 1756),
#  ('school', 1752),
#  ('later', 1750),
#  ('entire', 1738),
#  ('shows', 1720),
#  ('next', 1716),
#  ('john', 1716),
#  ('short', 1714),
#  ('seemed', 1714),
#  ('hollywood', 1700),
#  ('home', 1696),
#  ('true', 1692),
#  ('person', 1692),
#  ('absolutely', 1684),
#  ('sort', 1680),
#  ('care', 1678),
#  ('understand', 1672),
#  ('plays', 1670),
#  ('felt', 1668),
#  ('written', 1658),
#  ('title', 1656),
#  ('men', 1644),
#  ('until', 1642),
#  ('flick', 1632),
#  ('decent', 1630),
#  ('face', 1628),
#  ('friends', 1620),
#  ('stars', 1615),
#  ('job', 1614),
#  ('case', 1614),
#  ('itself', 1608),
#  ('yes', 1602),
#  ('perhaps', 1600),
#  ('went', 1594),
#  ('wanted', 1594),
#  ('called', 1592),
#  ('annoying', 1590),
#  ('ridiculous', 1580),
#  ('tries', 1580),
#  ('laugh', 1576),
#  ('evil', 1574),
#  ('along', 1572),
#  ('top', 1570),
#  ('hour', 1568),
#  ('full', 1566),
#  ('came', 1560),
#  ('writing', 1560),
#  ('keep', 1540),
#  ('totally', 1534),
#  ('playing', 1532),
#  ('god', 1530),
#  ('won', 1528),
#  ('guys', 1526),
#  ('already', 1524),
#  ('gore', 1514),
#  ('direction', 1496),
#  ('save', 1492),
#  ('lost', 1490),
#  ('example', 1489),
#  ('sound', 1484),
#  ('war', 1482),
#  ('attempt', 1470),
#  ('car', 1466),
#  ('except', 1466),
#  ('moments', 1464),
#  ('blood', 1464),
#  ('obviously', 1460),
#  ('act', 1458),
#  ('remember', 1456),
#  ('kill', 1454),
#  ('truly', 1452),
#  ('white', 1452),
#  ('father', 1452),
#  ('b', 1450),
#  ('thinking', 1440),
#  ('ok', 1432),
#  ('finally', 1432),
#  ('turn', 1422),
#  ('quality', 1402),
#  ('lack', 1396),
#  ('style', 1388),
#  ('wouldn', 1386),
#  ('cheap', 1382),
#  ('none', 1380),
#  ('kid', 1372),
#  ('please', 1372),
#  ('boy', 1370),
#  ('seriously', 1368),
#  ('lead', 1360),
#  ('dull', 1354),
#  ('children', 1352),
#  ('starts', 1351),
#  ('stuff', 1346),
#  ('hope', 1344),
#  ('looked', 1340),
#  ('recommend', 1338),
#  ('under', 1336),
#  ('run', 1334),
#  ('killed', 1334),
#  ('enjoy', 1332),
#  ('others', 1332),
#  ('etc', 1326),
#  ('myself', 1326),
#  ('beginning', 1324),
#  ('girls', 1324),
#  ('against', 1324),
#  ('obvious', 1320),
#  ('small', 1320),
#  ('hell', 1318),
#  ('slow', 1314),
#  ('hand', 1312),
#  ('wonder', 1304),
#  ('lame', 1304),
#  ('becomes', 1302),
#  ('picture', 1302),
#  ('based', 1300),
#  ('early', 1296),
#  ('behind', 1292),
#  ('poorly', 1288),
#  ('avoid', 1284),
#  ('apparently', 1280),
#  ('complete', 1280),
#  ('happens', 1278),
#  ('anyway', 1276),
#  ('classic', 1274),
#  ('several', 1272),
#  ('despite', 1270),
#  ('certainly', 1270),
#  ('episode', 1270),
#  ('often', 1262),
#  ('cut', 1260),
#  ('writer', 1260),
#  ('mother', 1256),
#  ('predictable', 1256),
#  ('gave', 1256),
#  ('become', 1254),
#  ('close', 1250),
#  ('fans', 1248),
#  ('saying', 1242),
#  ('scary', 1238),
#  ('stop', 1236),
#  ('live', 1236),
#  ('wants', 1234),
#  ('self', 1230),
#  ('mr', 1224),
#  ('jokes', 1222),
#  ('friend', 1222),
#  ('cannot', 1220),
#  ('overall', 1218),
#  ('cinema', 1208),
#  ('child', 1206),
#  ('silly', 1202),
#  ('beautiful', 1192),
#  ('human', 1190),
#  ('expect', 1188),
#  ('liked', 1186),
#  ('happened', 1184),
#  ('bunch', 1180),
#  ('entertaining', 1180),
#  ('actress', 1176),
#  ('final', 1176),
#  ('says', 1168),
#  ('performances', 1168),
#  ('turns', 1154),
#  ('humor', 1154),
#  ('themselves', 1152),
#  ('eyes', 1152),
#  ('hours', 1148),
#  ('happen', 1146),
#  ('basically', 1144),
#  ('days', 1144),
#  ('running', 1142),
#  ('involved', 1138),
#  ('disappointed', 1138),
#  ('call', 1138),
#  ('directed', 1136),
#  ('group', 1136),
#  ('fight', 1134),
#  ('daughter', 1132),
#  ('talking', 1132),
#  ('body', 1132),
#  ('badly', 1130),
#  ('sorry', 1130),
#  ('throughout', 1126),
#  ('viewer', 1126),
#  ('yourself', 1124),
#  ('extremely', 1124),
#  ('interest', 1122),
#  ('heard', 1122),
#  ('violence', 1122),
#  ('shots', 1118),
#  ('side', 1114),
#  ('word', 1112),
#  ('art', 1110),
#  ('possible', 1108),
#  ('dark', 1102),
#  ('game', 1102),
#  ('hero', 1100),
#  ('alone', 1098),
#  ('son', 1094),
#  ('type', 1094),
#  ('leave', 1094),
#  ('gives', 1092),
#  ('parts', 1092),
#  ('single', 1092),
#  ('started', 1090),
#  ('female', 1086),
#  ('rating', 1082),
#  ('mess', 1082),
#  ('voice', 1082),
#  ('aren', 1080),
#  ('town', 1080),
#  ('drama', 1076),
#  ('definitely', 1074),
#  ('unless', 1072),
#  ('review', 1068),
#  ('effort', 1066),
#  ('weak', 1066),
#  ('able', 1066),
#  ('took', 1062),
#  ('non', 1060),
#  ('five', 1060),
#  ('matter', 1058),
#  ('usually', 1058),
#  ('michael', 1056),
#  ('feeling', 1052),
#  ('huge', 1046),
#  ('sequel', 1044),
#  ('soon', 1042),
#  ('exactly', 1040),
#  ('turned', 1038),
#  ('past', 1038),
#  ('police', 1036),
#  ('tried', 1030),
#  ('middle', 1026),
#  ('talent', 1026),
#  ('genre', 1024),
#  ('zombie', 1020),
#  ('ends', 1018),
#  ('history', 1018),
#  ('straight', 1006),
#  ('opening', 1003),
#  ('serious', 1002),
#  ('coming', 1002),
#  ('moment', 1000),
#  ('lives', 998),
#  ('sad', 998),
#  ('dialog', 996),
#  ('particularly', 996),
#  ('editing', 986),
#  ('clearly', 984),
#  ('beyond', 982),
#  ('earth', 982),
#  ('taken', 980),
#  ('cool', 980),
#  ('level', 979),
#  ('dumb', 978),
#  ('okay', 976),
#  ('major', 974),
#  ('fast', 970),
#  ('premise', 970),
#  ('joke', 968),
#  ('stories', 968),
#  ('wasted', 966),
#  ('minute', 966),
#  ('across', 964),
#  ('mostly', 964),
#  ('rent', 964),
#  ('late', 962),
#  ('falls', 962),
#  ('fails', 962),
#  ('mention', 956),
#  ('theater', 950),
#  ('stay', 944),
#  ('sometimes', 944),
#  ('hit', 936),
#  ('talk', 934),
#  ('fine', 934),
#  ('die', 932),
#  ('storyline', 930),
#  ('pointless', 930),
#  ('taking', 928),
#  ('order', 924),
#  ('brother', 922),
#  ('whatever', 920),
#  ('told', 920),
#  ('wish', 916),
#  ('room', 912),
#  ('career', 910),
#  ('appears', 910),
#  ('write', 910),
#  ('known', 908),
#  ('husband', 908),
#  ('living', 902),
#  ('sit', 900),
#  ('ten', 900),
#  ('words', 898),
#  ('monster', 896),
#  ('chance', 896),
#  ('hate', 888),
#  ('novel', 888),
#  ('add', 886),
#  ('english', 886),
#  ('somehow', 882),
#  ('strange', 880),
#  ('imdb', 876),
#  ('actual', 876),
#  ('total', 874),
#  ('material', 874),
#  ('killing', 874),
#  ('ones', 874),
#  ('knew', 872),
#  ('king', 868),
#  ('number', 868),
#  ('using', 866),
#  ('lee', 862),
#  ('power', 862),
#  ('shown', 862),
#  ('works', 862),
#  ('giving', 862),
#  ('points', 860),
#  ('possibly', 860),
#  ('kept', 860),
#  ('four', 858),
#  ('local', 854),
#  ('usual', 852),
#  ('including', 850),
#  ('problems', 848),
#  ('ago', 848),
#  ('opinion', 848),
#  ('nudity', 846),
#  ('age', 844),
#  ('due', 842),
#  ('roles', 840),
#  ('writers', 838),
#  ('decided', 838),
#  ('near', 836),
#  ('flat', 836),
#  ('easily', 836),
#  ('murder', 834),
#  ('experience', 834),
#  ('reviews', 832),
#  ('imagine', 830),
#  ('feels', 826),
#  ('plain', 822),
#  ('somewhat', 822),
#  ('class', 820),
#  ('score', 820),
#  ('song', 818),
#  ('bring', 818),
#  ('whether', 818),
#  ('otherwise', 816),
#  ('whose', 816),
#  ('average', 816),
#  ('pathetic', 814),
#  ('nearly', 814),
#  ('knows', 814),
#  ('zombies', 814),
#  ('cinematography', 813),
#  ('cheesy', 812),
#  ('upon', 812),
#  ('city', 810),
#  ('space', 810),
#  ('credits', 808),
#  ('james', 806),
#  ('lots', 806),
#  ('change', 806),
#  ('entertainment', 804),
#  ('nor', 804),
#  ('wait', 802),
#  ('released', 800),
#  ('needs', 798),
#  ('shame', 796),
#  ('attention', 792),
#  ('comments', 788),
#  ('bored', 786),
#  ('free', 786),
#  ('lady', 786),
#  ('expected', 784),
#  ('needed', 784),
#  ('clear', 784),
#  ('view', 782),
#  ('development', 780),
#  ('check', 780),
#  ('doubt', 780),
#  ('figure', 778),
#  ('mystery', 778),
#  ('excellent', 776),
#  ('garbage', 776),
#  ('sequence', 772),
#  ('television', 772),
#  ('o', 770),
#  ('sets', 770),
#  ('laughable', 768),
#  ('potential', 768),
#  ('robert', 764),
#  ('light', 764),
#  ('country', 764),
#  ('documentary', 764),
#  ('reality', 764),
#  ('general', 763),
#  ('ask', 762),
#  ('comic', 760),
#  ('fall', 760),
#  ('begin', 760),
#  ('footage', 758),
#  ('stand', 758),
#  ('forced', 758),
#  ('trash', 758),
#  ('remake', 758),
#  ('thriller', 756),
#  ('songs', 756),
#  ('gay', 754),
#  ('within', 754),
#  ('hardly', 752),
#  ('above', 750),
#  ('gone', 750),
#  ('george', 748),
#  ('means', 746),
#  ('sounds', 746),
#  ('directing', 744),
#  ('move', 744),
#  ('david', 744),
#  ('buy', 744),
#  ('rock', 742),
#  ('forward', 742),
#  ('important', 742),
#  ('hot', 740),
#  ('haven', 740),
#  ('filmed', 740),
#  ('british', 740),
#  ('heart', 738),
#  ('reading', 738),
#  ('fake', 738),
#  ('incredibly', 736),
#  ('weird', 736),
#  ('hear', 736),
#  ('enjoyed', 734),
#  ('hilarious', 734),
#  ('cop', 734),
#  ('musical', 734),
#  ('message', 732),
#  ('happy', 732),
#  ('pay', 732),
#  ('laughs', 730),
#  ('box', 730),
#  ('suspense', 726),
#  ('sadly', 726),
#  ('eye', 724),
#  ('third', 723),
#  ('similar', 722),
#  ('named', 722),
#  ('modern', 720),
#  ('failed', 718),
#  ('events', 718),
#  ('forget', 716),
#  ('question', 716),
#  ('male', 714),
#  ('finds', 714),
#  ('perfect', 712),
#  ('spent', 710),
#  ('sister', 710),
#  ('feature', 708),
#  ('result', 708),
#  ('comment', 706),
#  ('girlfriend', 706),
#  ('sexual', 704),
#  ('attempts', 702),
#  ('neither', 702),
#  ('richard', 702),
#  ('screenplay', 700),
#  ('elements', 700),
#  ('spoilers', 698),
#  ('brain', 696),
#  ('filmmakers', 696),
#  ('showing', 696),
#  ('miss', 694),
#  ('dr', 694),
#  ('christmas', 694),
#  ('cover', 690),
#  ('red', 688),
#  ('sequences', 688),
#  ('typical', 686),
#  ('excuse', 686),
#  ('crazy', 685),
#  ('ideas', 684),
#  ('baby', 684),
#  ('loved', 682),
#  ('meant', 682),
#  ('worked', 680),
#  ('fire', 680),
#  ('unbelievable', 678),
#  ('follow', 678),
#  ('theme', 674),
#  ('barely', 672),
#  ('producers', 672),
#  ('twist', 672),
#  ('plus', 672),
#  ('appear', 672),
#  ('directors', 670),
#  ('team', 670),
#  ('viewers', 666),
#  ('leads', 664),
#  ('tom', 664),
#  ('slasher', 664),
#  ('wrote', 662),
#  ('villain', 662),
#  ('gun', 662),
#  ('working', 662),
#  ('island', 660),
#  ('strong', 660),
#  ('open', 660),
#  ('realize', 660),
#  ('positive', 658),
#  ('disappointing', 658),
#  ('yeah', 658),
#  ('quickly', 658),
#  ('weren', 656),
#  ('release', 656),
#  ('simple', 656),
#  ('honestly', 656),
#  ('eventually', 655),
#  ('period', 654),
#  ('tells', 654),
#  ('kills', 654),
#  ('doctor', 654),
#  ('nowhere', 652),
#  ('list', 652),
#  ('acted', 652),
#  ('herself', 652),
#  ('dog', 652),
#  ('walk', 650),
#  ('air', 648),
#  ('apart', 648),
#  ('makers', 646),
#  ('subject', 646),
#  ('learn', 644),
#  ('fi', 644),
#  ('sci', 638),
#  ('bother', 638),
#  ('admit', 638),
#  ('jack', 636),
#  ('disappointment', 636),
#  ('hands', 636),
#  ('note', 636),
#  ('certain', 634),
#  ('e', 634),
#  ('value', 634),
#  ('casting', 634),
#  ('grade', 632),
#  ('peter', 632),
#  ('suddenly', 630),
#  ('missing', 630),
#  ('form', 626),
#  ('stick', 626),
#  ('previous', 626),
#  ('break', 626),
#  ('soundtrack', 624),
#  ('surprised', 622),
#  ('front', 622),
#  ('expecting', 622),
#  ('parents', 620),
#  ('surprise', 620),
#  ('relationship', 620),
#  ('shoot', 618),
#  ('today', 618),
#  ('painful', 616),
#  ('ways', 616),
#  ('leaves', 616),
#  ('ended', 616),
#  ('creepy', 616),
#  ('concept', 616),
#  ('somewhere', 616),
#  ('vampire', 616),
#  ('future', 614),
#  ('spend', 614),
#  ('th', 614),
#  ('difficult', 612),
#  ('effect', 612),
#  ('fighting', 612),
#  ('street', 612),
#  ('c', 610),
#  ('america', 610),
#  ('accent', 608),
#  ('truth', 604),
#  ('project', 604),
#  ('joe', 602),
#  ('f', 602),
#  ('deal', 602),
#  ('indeed', 602),
#  ('biggest', 600),
#  ('rate', 600),
#  ('paul', 598),
#  ('japanese', 598),
#  ('utterly', 596),
#  ('begins', 596),
#  ('redeeming', 596),
#  ('college', 596),
#  ('york', 594),
#  ('fairly', 594),
#  ('disney', 594),
#  ('crew', 592),
#  ('create', 592),
#  ('cartoon', 592),
#  ('revenge', 592),
#  ('co', 590),
#  ('outside', 590),
#  ('computer', 590),
#  ('interested', 590),
#  ('stage', 590),
#  ('considering', 588),
#  ('speak', 588),
#  ('among', 588),
#  ('towards', 586),
#  ('channel', 586),
#  ('sick', 586),
#  ('talented', 584),
#  ('cause', 584),
#  ('particular', 584),
#  ('van', 584),
#  ('hair', 584),
#  ('bottom', 582),
#  ('reasons', 582),
#  ('mediocre', 580),
#  ('cat', 580),
#  ('telling', 580),
#  ('supporting', 578),
#  ('store', 578),
#  ('hoping', 576),
#  ('waiting', 576),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for w, count in list(total_counts.most_common()):
    if count > 99:
        pos_neg_ratios[w] = max(float(positive_counts[w]), 1) / max(float(negative_counts[w]), 1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.06082036342271
# Pos-to-neg ratio for 'amazing' = 4.038167938931298
# Pos-to-neg ratio for 'terrible' = 0.17757009345794392

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for w, ratio in pos_neg_ratios.most_common():
    pos_neg_ratios[w] = np.log(ratio)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05904253655359134
# Pos-to-neg ratio for 'amazing' = 1.3957911086571477
# Pos-to-neg ratio for 'terrible' = -1.7283898552954657

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.3844950627890888),
#  ('antwone', 5.1704839950381514),
#  ('din', 5.0998664278241987),
#  ('gunga', 4.8828019225863706),
#  ('goldsworthy', 4.8675344504555822),
#  ('gypo', 4.7874917427820458),
#  ('yokai', 4.7874917427820458),
#  ('paulie', 4.7706846244656651),
#  ('visconti', 4.6249728132842707),
#  ('flavia', 4.6249728132842707),
#  ('iturbi', 3.970291913552122),
#  ('gundam', 3.8286413964890951),
#  ('capote', 3.417726683613366),
#  ('excellently', 3.3843902633457743),
#  ('felix', 3.3758795736778655),
#  ('deanna', 3.3322045101752038),
#  ('hayworth', 3.3322045101752038),
#  ('fido', 3.2958368660043291),
#  ('sammo', 3.2580965380214821),
#  ('laputa', 3.2386784521643803),
#  ('vance', 3.2321210516182215),
#  ('kolchak', 3.2188758248682006),
#  ('sox', 3.120895416507997),
#  ('alvin', 3.1060803307228562),
#  ('mathieu', 3.0602707946915619),
#  ('biko', 3.0563568953704259),
#  ('gilliam', 3.0122615755052013),
#  ('polanski', 3.0056826044071592),
#  ('harriet', 2.9267394020670396),
#  ('matthau', 2.924504764265623),
#  ('chavez', 2.8903717578961645),
#  ('ultimatum', 2.8903717578961645),
#  ('ratso', 2.8763855159214247),
#  ('delightfully', 2.8134107167600364),
#  ('creasy', 2.7932080094425169),
#  ('corbett', 2.7725887222397811),
#  ('vonnegut', 2.7515353130419489),
#  ('victoria', 2.7500144002012421),
#  ('mclaglen', 2.7472709142554912),
#  ('mildred', 2.7362210780689065),
#  ('braveheart', 2.7245795030534206),
#  ('kazan', 2.7080502011022101),
#  ('sirk', 2.6741486494265287),
#  ('gandhi', 2.6567569067146595),
#  ('mccoy', 2.6390573296152584),
#  ('cheadle', 2.6390573296152584),
#  ('othello', 2.6026896854443837),
#  ('novak', 2.5902671654458267),
#  ('cal', 2.5839975524322312),
#  ('flawless', 2.5563656137701454),
#  ('christy', 2.553899521274952),
#  ('fuller', 2.5520459526256287),
#  ('ramones', 2.5520459526256287),
#  ('rea', 2.5257286443082556),
#  ('haines', 2.5257286443082556),
#  ('colman', 2.5257286443082556),
#  ('winchester', 2.5176964726109912),
#  ('chamberlain', 2.5014359517392109),
#  ('northam', 2.4638532405901681),
#  ('stardust', 2.4423470353692043),
#  ('carla', 2.4107986776342782),
#  ('sabrina', 2.3978952727983707),
#  ('kinnear', 2.3978952727983707),
#  ('peters', 2.3848231912310176),
#  ('tenant', 2.3826278006675823),
#  ('superbly', 2.3470368555648795),
#  ('raines', 2.3307559699607419),
#  ('georges', 2.3191143949452564),
#  ('trier', 2.2857779746776643),
#  ('rukh', 2.2772672850097559),
#  ('dixon', 2.2454266791540971),
#  ('miyazaki', 2.2380465718564744),
#  ('perfection', 2.2284771208403238),
#  ('edith', 2.2192034840549946),
#  ('astaire', 2.2141741356499924),
#  ('malone', 2.1972245773362196),
#  ('mol', 2.1812242359897782),
#  ('scoop', 2.1649637151179979),
#  ('pickford', 2.1649637151179979),
#  ('zorro', 2.1594842493533721),
#  ('dandy', 2.1316272948504063),
#  ('voight', 2.1102132003465894),
#  ('heartbreaking', 2.1102132003465894),
#  ('captures', 2.0794415416798357),
#  ('wang', 2.0794415416798357),
#  ('truman', 2.0794415416798357),
#  ('sunrise', 2.0794415416798357),
#  ('sg', 2.0614230361771577),
#  ('masterson', 2.0614230361771577),
#  ('hawke', 2.0512706647131398),
#  ('wonderfully', 2.0485643031153966),
#  ('expertly', 2.0430738975089611),
#  ('masterful', 2.0412203288596382),
#  ('tomei', 2.0368819272610401),
#  ('brosnan', 2.0193376176101303),
#  ('powell', 2.0175661379617482),
#  ('europa', 2.0149030205422647),
#  ('greene', 2.0149030205422647),
#  ('cypher', 2.0053335695261141),
#  ('darren', 1.9878743481543455),
#  ('pegg', 1.9859154836690125),
#  ('lily', 1.9810014688665833),
#  ('bakshi', 1.9636097261547143),
#  ('lincoln', 1.9459101490553132),
#  ('carell', 1.9459101490553132),
#  ('montana', 1.9339339580085977),
#  ('walsh', 1.9195928407379399),
#  ('lemmon', 1.9148195619852821),
#  ('explores', 1.9136492868370918),
#  ('steele', 1.9136492868370918),
#  ('breathtaking', 1.8925641683500207),
#  ('refreshing', 1.891548939836426),
#  ('bourne', 1.8870696490323797),
#  ('ira', 1.8827312474337816),
#  ('deliciously', 1.8827312474337816),
#  ('chess', 1.8538912503350613),
#  ('flynn', 1.8484548129046001),
#  ('affection', 1.8405496333974869),
#  ('homer', 1.8382794848629478),
#  ('soccer', 1.8268507890393251),
#  ('delightful', 1.8262456452992242),
#  ('kidman', 1.824549292051046),
#  ('andrews', 1.8230120127321594),
#  ('lumet', 1.8152899666382492),
#  ('determination', 1.8152899666382492),
#  ('nina', 1.8101086078962514),
#  ('sopranos', 1.8067973465925955),
#  ('paula', 1.791759469228055),
#  ('deliverance', 1.791759469228055),
#  ('elvira', 1.7841548698428356),
#  ('beautifully', 1.7784436932522829),
#  ('reeve', 1.7730673362159026),
#  ('ae', 1.7707060600302227),
#  ('gripping', 1.7609878105613013),
#  ('tierney', 1.7609878105613013),
#  ('soylent', 1.754019141245208),
#  ('gershwin', 1.7491998548092591),
#  ('underrated', 1.747956846569662),
#  ('technicolor', 1.7346010553881064),
#  ('kline', 1.729239112246721),
#  ('sadness', 1.7206635475443246),
#  ('superb', 1.7189076208420597),
#  ('delight', 1.7122952978738082),
#  ('dustin', 1.6945957207744073),
#  ('welles', 1.693024628542366),
#  ('clara', 1.6863989535702288),
#  ('liu', 1.6863989535702288),
#  ('einstein', 1.6863989535702288),
#  ('kurosawa', 1.6835458845878224),
#  ('macy', 1.6817585740137264),
#  ('timeless', 1.6805338341178306),
#  ('grayson', 1.6784307839210517),
#  ('hartley', 1.6700625342505353),
#  ('mesmerizing', 1.6677068205580761),
#  ('sinatra', 1.6643145226599347),
#  ('unforgettable', 1.6602963296675914),
#  ('delirious', 1.6582280766035324),
#  ('johansson', 1.6582280766035324),
#  ('shanghai', 1.65455834771457),
#  ('fairbanks', 1.6529230243738393),
#  ('touching', 1.6514021115331325),
#  ('favorites', 1.6486586255873816),
#  ('iran', 1.6486586255873816),
#  ('wrenching', 1.6486586255873816),
#  ('heartwarming', 1.6451559950361796),
#  ('extraordinary', 1.6445292322453706),
#  ('sullivan', 1.6411866107486806),
#  ('lang', 1.6314168191528755),
#  ('rowlands', 1.6314168191528755),
#  ('election', 1.6274564179367788),
#  ('stewart', 1.6249021381316819),
#  ('watson', 1.6236225474260568),
#  ('brilliantly', 1.6191467265610613),
#  ('palma', 1.6094379124341003),
#  ('understated', 1.6094379124341003),
#  ('simmons', 1.6094379124341003),
#  ('elliott', 1.6094379124341003),
#  ('conveys', 1.5926307941177191),
#  ('loy', 1.589235205116581),
#  ('friendship', 1.588384503236268),
#  ('ritter', 1.5830046553659449),
#  ('nathan', 1.5804503755608481),
#  ('buffalo', 1.5804503755608481),
#  ('scrooge', 1.5712166996139025),
#  ('magnificent', 1.5686159179138452),
#  ('jackie', 1.5686159179138452),
#  ('odyssey', 1.5686159179138452),
#  ('wonderful', 1.5680329974659779),
#  ('finest', 1.5668782980153044),
#  ('sondra', 1.563975538357343),
#  ('tremendous', 1.5629178967992075),
#  ('heartfelt', 1.5621850275835547),
#  ('spock', 1.5581446180465499),
#  ('sidewalk', 1.547562508716013),
#  ('absorbing', 1.547562508716013),
#  ('longing', 1.547562508716013),
#  ('cunningham', 1.547562508716013),
#  ('delicate', 1.5404450409471491),
#  ('soprano', 1.5404450409471491),
#  ('jose', 1.5404450409471491),
#  ('hyde', 1.5362345084108056),
#  ('astonishing', 1.5353299402803786),
#  ('andre', 1.5353299402803786),
#  ('stack', 1.5353299402803786),
#  ('pleasantly', 1.5339303599259553),
#  ('mann', 1.5339303599259553),
#  ('jedi', 1.5339303599259553),
#  ('freedom', 1.5321047090309301),
#  ('kitty', 1.5293952047605639),
#  ('hadley', 1.5260563034950492),
#  ('sidney', 1.5246966839790097),
#  ('iranian', 1.5163474893680884),
#  ('detract', 1.5141277326297755),
#  ('sassy', 1.5125880864441827),
#  ('fontaine', 1.5125880864441827),
#  ('nancy', 1.5121746070088933),
#  ('fantastic', 1.5117638297004306),
#  ('stargate', 1.5114575040738967),
#  ('terrific', 1.5090191646870532),
#  ('marvelous', 1.5079014932146777),
#  ('noir', 1.5069971068796089),
#  ('outstanding', 1.5040773967762742),
#  ('marie', 1.5040773967762742),
#  ('ruth', 1.5040773967762742),
#  ('layers', 1.5040773967762742),
#  ('demille', 1.5040773967762742),
#  ('jacques', 1.5040773967762742),
#  ('gielgud', 1.5040773967762742),
#  ('definitive', 1.493925025312256),
#  ('macarthur', 1.4916548767777169),
#  ('stark', 1.488077055429833),
#  ('denis', 1.4781019103730135),
#  ('stanwyck', 1.4739999415389962),
#  ('splendid', 1.4696759700589417),
#  ('widmark', 1.4689860769650041),
#  ('excellent', 1.4673278545675326),
#  ('tender', 1.4622802680978126),
#  ('pathos', 1.4586150226995167),
#  ('exceptional', 1.455287232606842),
#  ('ruby', 1.4534336639575192),
#  ('gentle', 1.452252328911688),
#  ('chan', 1.4484261422268967),
#  ('cerebral', 1.4469189829363254),
#  ('restrained', 1.4469189829363254),
#  ('dickens', 1.4403615823901663),
#  ('poignant', 1.4350845252893227),
#  ('sentinel', 1.4350845252893227),
#  ('neglected', 1.4350845252893227),
#  ('rewarding', 1.4307461236907244),
#  ('captivating', 1.4288539755386864),
#  ('elegant', 1.4271163556401458),
#  ('fisher', 1.4255150742731719),
#  ('davies', 1.4255150742731719),
#  ('pixar', 1.4240346891027378),
#  ('chilling', 1.4161473242695717),
#  ('gerard', 1.413693335308005),
#  ('fleet', 1.410986973710262),
#  ('juliette', 1.4087672169719492),
#  ('vanilla', 1.4087672169719492),
#  ('darker', 1.4078005663408544),
#  ('gem', 1.4072010459392044),
#  ('standout', 1.4069136483226263),
#  ('stunningly', 1.4069136483226263),
#  ('amrita', 1.4069136483226263),
#  ('uplifting', 1.4017985476558559),
#  ('april', 1.3987168811184478),
#  ('amazing', 1.3957911086571477),
#  ('blake', 1.3862943611198906),
#  ('cushing', 1.3862943611198906),
#  ('delicious', 1.3862943611198906),
#  ('thelma', 1.3862943611198906),
#  ('enchanted', 1.3862943611198906),
#  ('reiser', 1.3862943611198906),
#  ('gentleman', 1.37147927533475),
#  ('marc', 1.3705460041517514),
#  ('overlooked', 1.366876275262789),
#  ('errol', 1.366876275262789),
#  ('engrossing', 1.366876275262789),
#  ('ralph', 1.3609765531356006),
#  ('kelly', 1.3574739225843986),
#  ('swim', 1.3564413979702095),
#  ('bud', 1.3564413979702095),
#  ('preminger', 1.3523928094442093),
#  ('neill', 1.3499267169490159),
#  ('cole', 1.3485540331370436),
#  ('dalton', 1.3480731482996928),
#  ('bette', 1.346448452572691),
#  ('richardson', 1.3460204619819507),
#  ('hoffman', 1.3403846598158127),
#  ('sailor', 1.3397743454849977),
#  ('pfeiffer', 1.3397743454849977),
#  ('shines', 1.3366974199805186),
#  ('winters', 1.3277981544382822),
#  ('scariest', 1.3268709406490899),
#  ('loneliness', 1.3217558399823195),
#  ('divine', 1.3217558399823195),
#  ('frontier', 1.3217558399823195),
#  ('vivid', 1.3188530803243581),
#  ('notch', 1.3185761870649397),
#  ('orleans', 1.3143208614948014),
#  ('giallo', 1.3137236682850553),
#  ('riveting', 1.3121863889661687),
#  ('pitt', 1.3103084541419687),
#  ('cleverly', 1.3083328196501789),
#  ('powerful', 1.3075134832667763),
#  ('psychiatrist', 1.3062516534463542),
#  ('strengths', 1.3062516534463542),
#  ('remarkable', 1.3034067013141228),
#  ('garbo', 1.3034067013141228),
#  ('portrait', 1.3022112439093492),
#  ('gritty', 1.2992829841302609),
#  ('innocence', 1.2992829841302609),
#  ('ensemble', 1.2964380319980295),
#  ('holly', 1.2953225829141639),
#  ('september', 1.2947271675944001),
#  ('alexandre', 1.2927683031090671),
#  ('panic', 1.2919836816486494),
#  ('paxton', 1.2878542883066382),
#  ('burns', 1.2851982442485219),
#  ('rookie', 1.2851982442485219),
#  ('energetic', 1.2851982442485219),
#  ('vividly', 1.2851982442485219),
#  ('accessible', 1.2851982442485219),
#  ('philip', 1.2809338454620642),
#  ('carol', 1.2809338454620642),
#  ('barbara', 1.2767321586083644),
#  ('rural', 1.2762934659055623),
#  ('cultures', 1.2762934659055623),
#  ('lavish', 1.2762934659055623),
#  ('vega', 1.2762934659055623),
#  ('alison', 1.2750687260096663),
#  ('stunning', 1.2734150130480371),
#  ('neatly', 1.2729656758128876),
#  ('brooklyn', 1.2712250313351035),
#  ('favorite', 1.2705924916673317),
#  ('builds', 1.2697605448639391),
#  ('appreciated', 1.2692378056988731),
#  ('sissy', 1.2685113254635072),
#  ('pierce', 1.2685113254635072),
#  ('maureen', 1.2656663733312759),
#  ('sterling', 1.2656663733312759),
#  ('devastating', 1.2636920390275583),
#  ('coup', 1.2622417124499117),
#  ('rifle', 1.2611312181658845),
#  ('unfolds', 1.258954938743289),
#  ('favourite', 1.2547180033311713),
#  ('bacall', 1.2527629684953681),
#  ('bsg', 1.2527629684953681),
#  ('phenomenal', 1.2527629684953681),
#  ('cuban', 1.2527629684953681),
#  ('perfect', 1.2495475316413938),
#  ('von', 1.2492725635555995),
#  ('journey', 1.2469149986129449),
#  ('bond', 1.2452157628599851),
#  ('posey', 1.2443240998495033),
#  ('anton', 1.2431935174792172),
#  ('sublime', 1.2417131323087831),
#  ('berkeley', 1.2417131323087831),
#  ('rita', 1.2367626271489269),
#  ('reflects', 1.2347444629926896),
#  ('brilliant', 1.2324522756478047),
#  ('masterfully', 1.2321436812926323),
#  ('bravo', 1.2321436812926323),
#  ('beckinsale', 1.2286654169163074),
#  ('reign', 1.2272296664902032),
#  ('recommended', 1.2253639943072534),
#  ('viewings', 1.2237754316221157),
#  ('crafted', 1.2222262446352863),
#  ('troubled', 1.2219913098286144),
#  ('consequences', 1.221672381425337),
#  ('daniel', 1.2205021062771466),
#  ('championship', 1.2144441041932312),
#  ('ustinov', 1.2144441041932312),
#  ('kyle', 1.2130226398458539),
#  ('alexander', 1.2110902720948),
#  ('ladder', 1.2098379237783341),
#  ('prince', 1.2083112059245342),
#  ('solo', 1.2083112059245342),
#  ('boxing', 1.2074151485169087),
#  ('perfectly', 1.2039728043259361),
#  ('karl', 1.2039728043259361),
#  ('lends', 1.2039728043259361),
#  ('aftermath', 1.2039728043259361),
#  ('unusually', 1.2039728043259361),
#  ('haunting', 1.2001920814860301),
#  ('cinderella', 1.1984017592764806),
#  ('clan', 1.1977031913123406),
#  ('curtis', 1.1948403207626634),
#  ('marion', 1.1939224684724346),
#  ('depicts', 1.1895840668738364),
#  ('mice', 1.1895840668738364),
#  ('paramount', 1.1871656860095547),
#  ('emotions', 1.1862339799885544),
#  ('exquisite', 1.1837700970084166),
#  ('subtle', 1.1831696766961728),
#  ('loretta', 1.1786549963416462),
#  ('globe', 1.1786549963416462),
#  ('vibrant', 1.1786549963416462),
#  ('manners', 1.1786549963416462),
#  ('daughters', 1.176777061517446),
#  ('herbert', 1.1727202608218317),
#  ('courage', 1.1720397572229269),
#  ('dentist', 1.1700712526502546),
#  ('draws', 1.1676051601550612),
#  ('irene', 1.1676051601550612),
#  ('lola', 1.1676051601550612),
#  ('caron', 1.1676051601550612),
#  ('loyalty', 1.1664348850068709),
#  ('rare', 1.1661225801948385),
#  ('realities', 1.1631508098056809),
#  ('damon', 1.1601701816675432),
#  ('nominated', 1.1596068013709517),
#  ('loved', 1.1592944098376925),
#  ('cried', 1.1564318595569358),
#  ('everyday', 1.1553076323446549),
#  ('orson', 1.1549652252192415),
#  ('fay', 1.1544927470625663),
#  ('corruption', 1.1526795099383853),
#  ('playwright', 1.1526795099383853),
#  ('newman', 1.1499055830556602),
#  ('arkin', 1.148622709242771),
#  ('owl', 1.148622709242771),
#  ('tony', 1.1476543737357123),
#  ('contrast', 1.1468143904859875),
#  ('highly', 1.1456244706651642),
#  ('isolation', 1.1451323043030026),
#  ('packs', 1.1451323043030026),
#  ('fabulous', 1.144074662744867),
#  ('ned', 1.1430640512389434),
#  ('simplicity', 1.1430640512389434),
#  ('dazzling', 1.1420974006078486),
#  ('contribution', 1.1420974006078486),
#  ('shelley', 1.1411719030869056),
#  ('smooth', 1.1407237740182365),
#  ('emma', 1.1386176232818088),
#  ('dramas', 1.1370785694959058),
#  ('sensitive', 1.1357912919098638),
#  ('beatles', 1.1349799328389845),
#  ('vader', 1.1349799328389845),
#  ('wwe', 1.133098464739279),
#  ('deniro', 1.1314021114911006),
#  ('warmth', 1.1298648321722142),
#  ('tends', 1.1298648321722142),
#  ('inspiring', 1.1284652518177909),
#  ('june', 1.1284652518177909),
#  ('thoughtful', 1.1260112628562242),
#  ('stellar', 1.1249295969854831),
#  ('psyche', 1.1239300966523995),
#  ('vintage', 1.122142786078304),
#  ('macabre', 1.120591195386885),
#  ('mitch', 1.1192315758708453),
#  ('fishburne', 1.1192315758708453),
#  ('prominent', 1.1180303745252111),
#  ('rounded', 1.1180303745252111),
#  ('renaissance', 1.1169614273363062),
#  ('poem', 1.1143606456362487),
#  ('intimate', 1.1136501660326501),
#  ('helps', 1.1134824511475612),
#  ('affect', 1.1130010261202095),
#  ('diana', 1.1118575154181303),
#  ('adorable', 1.1118575154181303),
#  ('hank', 1.1113513144455394),
#  ('blend', 1.1104467463151124),
#  ('carrie', 1.1100409844917325),
#  ('shy', 1.1093075777848576),
#  ('depression', 1.1089750757036563),
#  ('jimmy', 1.1083684636134743),
#  ('today', 1.1082741995798466),
#  ('rival', 1.1069110914828049),
#  ('awesome', 1.1013633220399996),
#  ('tragic', 1.0986122886681098),
#  ('intense', 1.0986122886681098),
#  ('achievement', 1.0986122886681098),
#  ('glorious', 1.0986122886681098),
#  ('dub', 1.0986122886681098),
#  ('esther', 1.0986122886681098),
#  ('wilder', 1.0986122886681098),
#  ('enhanced', 1.0986122886681098),
#  ('collette', 1.0986122886681098),
#  ('cliffhanger', 1.0986122886681098),
#  ('fassbinder', 1.0986122886681098),
#  ('wider', 1.0986122886681098),
#  ('unique', 1.0944106018144097),
#  ('provides', 1.0910076892828904),
#  ('bettie', 1.0904489780289488),
#  ('unexpected', 1.087973890463054),
#  ('ideal', 1.0857088838322018),
#  ('lena', 1.085189268335969),
#  ('happiness', 1.0843263314206333),
#  ('palance', 1.0818051703517284),
#  ('laurence', 1.0809127115687087),
#  ('terrifying', 1.0799201556559572),
#  ('oldest', 1.0799201556559572),
#  ('muppets', 1.0799201556559572),
#  ('fears', 1.0775588794702773),
#  ('startling', 1.0775588794702773),
#  ('gable', 1.0775588794702773),
#  ('bloom', 1.0775588794702773),
#  ('subtly', 1.0775588794702773),
#  ('goodman', 1.0726368022648489),
#  ('artistry', 1.0726368022648489),
#  ('sandra', 1.0715836162801904),
#  ('restored', 1.0691984034618165),
#  ('waitress', 1.0678406300013561),
#  ('der', 1.0678406300013561),
#  ('davis', 1.065089596629466),
#  ('definite', 1.0647107369924282),
#  ('difficulties', 1.0647107369924282),
#  ('kansas', 1.0647107369924282),
#  ('hong', 1.0640067594906342),
#  ('rhythm', 1.0608719606852626),
#  ('seasons', 1.0596101308648405),
#  ('authorities', 1.0586069540544105),
#  ('thrilled', 1.0586069540544105),
#  ('boyer', 1.0586069540544105),
#  ('carries', 1.0581209273133727),
#  ('beauty', 1.0563099089774204),
#  ('robinson', 1.0560526742493137),
#  ('bands', 1.0560526742493137),
#  ('nominations', 1.0560526742493137),
#  ('fragile', 1.0531499145913523),
#  ('nightclub', 1.0531499145913523),
#  ('miranda', 1.0531499145913523),
#  ('touched', 1.052092273033217),
#  ('fascinating', 1.0513061712711727),
#  ('satisfying', 1.0498221244986776),
#  ('diverse', 1.0498221244986776),
#  ('sang', 1.0498221244986776),
#  ('enterprise', 1.0479685558493548),
#  ('sweden', 1.0459685551826878),
#  ('bosses', 1.0459685551826878),
#  ('beckham', 1.0459685551826878),
#  ('aunt', 1.0453677741492975),
#  ('gillian', 1.0445450673978338),
#  ('comparisons', 1.0414538748281612),
#  ('creates', 1.0396139479061539),
#  ('walter', 1.039423417277779),
#  ('spectacular', 1.0350988829457839),
#  ('galaxy', 1.0340737675305385),
#  ('limitations', 1.0340737675305385),
#  ('wonderland', 1.0340737675305385),
#  ('passionate', 1.032362903126909),
#  ('musicals', 1.0311710078725771),
#  ('greatest', 1.0299837822790134),
#  ('triumph', 1.0296194171811581),
#  ('margaret', 1.0296194171811581),
#  ('seymour', 1.0296194171811581),
#  ('pierre', 1.0296194171811581),
#  ('mature', 1.0266387890430204),
#  ('vulnerable', 1.0266387890430204),
#  ('portrayal', 1.0264159974636204),
#  ('ann', 1.0258529343856813),
#  ('immigrant', 1.0245043165143877),
#  ('dynamics', 1.0245043165143877),
#  ('ingenious', 1.0216512475319812),
#  ('cher', 1.0216512475319812),
#  ('deeply', 1.0211805485352936),
#  ('eugene', 1.0198314108149955),
#  ('navy', 1.017923377417967),
#  ('joey', 1.0169342576538425),
#  ('eleven', 1.0169342576538425),
#  ('conrad', 1.0169342576538425),
#  ('lucas', 1.0163741904311376),
#  ('vengeance', 1.0152306797290584),
#  ('incredible', 1.012812298864777),
#  ('widow', 1.0116009116784799),
#  ('recognition', 1.0116009116784799),
#  ('provocative', 1.0116009116784799),
#  ('pirate', 1.0116009116784799),
#  ('balance', 1.0094845087721023),
#  ('carrey', 1.0090001299784226),
#  ('brazil', 1.0086640520051702),
#  ('awe', 1.0082282271998408),
#  ('guilt', 1.0068047394149868),
#  ('glover', 1.0068047394149868),
#  ('ricky', 1.0055218656020977),
#  ('inventive', 1.0045833390198333),
#  ('essence', 1.0042026041970351),
#  ('integrity', 1.0033021088637848),
#  ('sons', 1.0024684281152074),
#  ('sport', 1.0021520224805474),
#  ('warm', 1.0011139241832319),
#  ('pokemon', 1.000631880307906),
#  ('convincingly', 1.000631880307906),
#  ('harry', 0.99980136474732484),
#  ('ages', 0.9993140676858292),
#  ('destiny', 0.99852883011112725),
#  ('relax', 0.99852883011112725),
#  ('july', 0.99852883011112725),
#  ('detroit', 0.99852883011112725),
#  ('eerie', 0.99714282850325009),
#  ('sweet', 0.99613361938517231),
#  ('judd', 0.99542805243287902),
#  ('learns', 0.99507160972726938),
#  ('holmes', 0.99493385919326827),
#  ('rosemary', 0.99325177301028345),
#  ('oscar', 0.991501712902498),
#  ('facing', 0.990398704027877),
#  ('poetic', 0.990398704027877),
#  ('unusual', 0.98971820042897229),
#  ('ginger', 0.98941299670311778),
#  ('laurie', 0.98861139345378124),
#  ('jules', 0.98861139345378124),
#  ('lonely', 0.98815529310379902),
#  ('grim', 0.98815529310379902),
#  ('nolte', 0.98738665355788524),
#  ('thrillers', 0.98690829908810851),
#  ('compassion', 0.98649499054740353),
#  ('complex', 0.98620272107286944),
#  ('willis', 0.98581679452276538),
#  ('vhs', 0.98407074693589713),
#  ('solid', 0.98265240757324135),
#  ('cox', 0.98082925301172619),
#  ('comfortable', 0.98082925301172619),
#  ('mistress', 0.98082925301172619),
#  ('keen', 0.98082925301172619),
#  ('mirrors', 0.98082925301172619),
#  ('arranged', 0.98082925301172619),
#  ('debut', 0.97906713801832701),
#  ('hooked', 0.97753435711487369),
#  ('stanley', 0.97537964824416146),
#  ('beautiful', 0.9749394589556627),
#  ('casablanca', 0.97186058302896583),
#  ('rose', 0.97145711318286299),
#  ('tears', 0.97094914441201907),
#  ('raymond', 0.97077891715822484),
#  ('hara', 0.9675840262617057),
#  ('spinal', 0.9675840262617057),
#  ('nomination', 0.96684301103698644),
#  ('winning', 0.96508089604358704),
#  ('minnelli', 0.96508089604358704),
#  ('mysteries', 0.96343751029985703),
#  ('hal', 0.96343751029985703),
#  ('mgm', 0.96248011434352965),
#  ('perry', 0.96227584511597841),
#  ('paris', 0.96167373772197273),
#  ('blunt', 0.96141116715462471),
#  ('feelings', 0.96006726156329714),
#  ('lovable', 0.95551144502743635),
#  ('attitudes', 0.95551144502743635),
#  ('courtroom', 0.95551144502743635),
#  ('heart', 0.95509443084291101),
#  ('leo', 0.9526583760450299),
#  ('youthful', 0.95097628986204519),
#  ('natured', 0.95097628986204519),
#  ('painter', 0.95097628986204519),
#  ('danny', 0.95048209662243432),
#  ('lifestyle', 0.95019228354983643),
#  ('themes', 0.94962715214174698),
#  ('anime', 0.9485989751068129),
#  ('masterpiece', 0.9473813189441862),
#  ('guinness', 0.9473813189441862),
#  ('gradually', 0.94614369502383622),
#  ('joy', 0.94513888621181341),
#  ('louis', 0.94446160884085151),
#  ('replies', 0.94446160884085151),
#  ('varied', 0.94446160884085151),
#  ('kennedy', 0.94260804019152855),
#  ('urban', 0.94236297218393017),
#  ('doubts', 0.9420432279765697),
#  ('unpredictable', 0.9420432279765697),
#  ('voyage', 0.94098334446452658),
#  ('combines', 0.94098334446452658),
#  ('goods', 0.94098334446452658),
#  ('downs', 0.94098334446452658),
#  ('subsequent', 0.93954759403842225),
#  ('italy', 0.93928025009885385),
#  ('mutual', 0.93826963859293022),
#  ('iconic', 0.93609335917033476),
#  ('cope', 0.93609335917033476),
#  ('allows', 0.93581715422451039),
#  ('charming', 0.93269676726126505),
#  ('winter', 0.93155820400494349),
#  ('spy', 0.92998957623231693),
#  ('highest', 0.92953595862417571),
#  ('romances', 0.92953595862417571),
#  ('nuances', 0.92953595862417571),
#  ('secrets', 0.92871325187271225),
#  ('colours', 0.92798677163734633),
#  ('fatale', 0.92798677163734633),
#  ('impact', 0.92754788639878949),
#  ('pleased', 0.92734056806074006),
#  ('norman', 0.92734056806074006),
#  ('christie', 0.92676203174145044),
#  ('reflection', 0.92494879461726964),
#  ('raw', 0.9242589015233319),
#  ('lively', 0.9242589015233319),
#  ('reveals', 0.9239536046197242),
#  ('treat', 0.92286249703738954),
#  ('danes', 0.9223330463301177),
#  ('colorful', 0.92115692152532802),
#  ('surprising', 0.92093111143065731),
#  ('loving', 0.92072532894202075),
#  ('thief', 0.92072532894202075),
#  ('quiet', 0.91875682436934858),
#  ('kudos', 0.91629073187415511),
#  ('bleak', 0.91629073187415511),
#  ('todd', 0.91629073187415511),
#  ('moody', 0.91629073187415511),
#  ('palace', 0.91629073187415511),
#  ('troubles', 0.91629073187415511),
#  ('portrayals', 0.91629073187415511),
#  ('walt', 0.91629073187415511),
#  ('establish', 0.91629073187415511),
#  ('jewel', 0.91629073187415511),
#  ('funniest', 0.91044845624992665),
#  ('belushi', 0.90825856017689077),
#  ('woo', 0.90755705190540037),
#  ('seldom', 0.90755705190540037),
#  ('muppet', 0.90672128085800441),
#  ('departure', 0.90570862254361817),
#  ('differently', 0.90570862254361817),
#  ('lasting', 0.90570862254361817),
#  ('subtitles', 0.90532170050358107),
#  ('crisp', 0.90445627422715225),
#  ('fonda', 0.90371194966729496),
#  ('compelling', 0.90359790507573612),
#  ('baseball', 0.90330353634734395),
#  ('darth', 0.9028677115420144),
#  ('debra', 0.9028677115420144),
#  ('season', 0.90274650676639789),
#  ('winner', 0.90125285450961445),
#  ('castle', 0.89982945482008303),
#  ('celebration', 0.89794159320595857),
#  ('eastwood', 0.89608802455663572),
#  ('tragedy', 0.89511573473769646),
#  ('essential', 0.89478452665319141),
#  ('paranoia', 0.8938178760220965),
#  ('inspirational', 0.8938178760220965),
#  ('despair', 0.89199803930511046),
#  ('optimistic', 0.89097292388986515),
#  ('nicely', 0.89067815601742883),
#  ('intensity', 0.88985747480599964),
#  ('focuses', 0.88952049080955031),
#  ('great', 0.88829404916479027),
#  ('worlds', 0.88730319500090271),
#  ('health', 0.88583152438944646),
#  ('drake', 0.88503818837005055),
#  ('arthur', 0.88460122091717253),
#  ('bates', 0.88420241732265448),
#  ('trials', 0.88420241732265448),
#  ('niece', 0.88420241732265448),
#  ('gorgeous', 0.88238918019847368),
#  ('nicole', 0.88238918019847368),
#  ('witty', 0.88066355423100395),
#  ('purple', 0.88035872264809167),
#  ('deliberate', 0.88035872264809167),
#  ('subway', 0.88035872264809167),
#  ('worms', 0.88035872264809167),
#  ('amazon', 0.87924946019380601),
#  ('quaid', 0.87924946019380601),
#  ('rob', 0.87771845708791529),
#  ('natural', 0.87730528516120132),
#  ('lucy', 0.87724021700228194),
#  ('deeper', 0.87707001872087376),
#  ('magical', 0.8769296579935747),
#  ('carey', 0.87546873735389985),
#  ('lukas', 0.87546873735389985),
#  ('informative', 0.87546873735389985),
#  ('enjoyed', 0.8734230496306068),
#  ('craig', 0.87082835779739776),
#  ('modesty', 0.87082835779739776),
#  ('christina', 0.87082835779739776),
#  ('spine', 0.87082835779739776),
#  ('sings', 0.86977071623926216),
#  ('appreciation', 0.86903784702360953),
#  ('weaknesses', 0.86750056770472306),
#  ('acceptance', 0.86750056770472306),
#  ('marvel', 0.86750056770472306),
#  ('morris', 0.86681067461078543),
#  ('achieves', 0.86499743748660451),
#  ('duel', 0.86499743748660451),
#  ('whites', 0.86499743748660451),
#  ('gibson', 0.86499743748660451),
#  ('obtain', 0.86222351060387925),
#  ('tear', 0.86113891179907498),
#  ('lovely', 0.86081157955392651),
#  ('moving', 0.85959538819760972),
#  ('icon', 0.8586616190375187),
#  ('disagree', 0.85822693091939395),
#  ('relate', 0.8574502318512216),
#  ('hart', 0.8564722366632449),
#  ('embrace', 0.85566611005772031),
#  ('jealousy', 0.85566611005772031),
#  ('melvyn', 0.85566611005772031),
#  ('crippled', 0.85566611005772031),
#  ('towers', 0.85441532815606758),
#  ('memorable', 0.85302443294440489),
#  ('arrival', 0.85277732615182922),
#  ('smiling', 0.85277732615182922),
#  ('widely', 0.85277732615182922),
#  ('dave', 0.8513711857748395),
#  ('princess', 0.84971624125148526),
#  ('jake', 0.84729786038720367),
#  ('forbidden', 0.84729786038720367),
#  ('widescreen', 0.84729786038720367),
#  ('confident', 0.84729786038720367),
#  ('understands', 0.84729786038720367),
#  ('residents', 0.84729786038720367),
#  ('smith', 0.84633214326724471),
#  ('episodes', 0.84577694754649702),
#  ('kung', 0.84533899590187067),
#  ('strong', 0.84469707868714616),
#  ('apartment', 0.84308732785086016),
#  ('columbo', 0.84267891453090915),
#  ('businessman', 0.84156718567821853),
#  ('martha', 0.84078317936600999),
#  ('challenges', 0.84078317936600999),
#  ('brendan', 0.84078317936600999),
#  ('realizes', 0.84012937090859119),
#  ('miniseries', 0.83975065475182076),
#  ('carmen', 0.83975065475182076),
#  ('approaches', 0.83975065475182076),
#  ('manager', 0.8383291904044432),
#  ('invention', 0.8383291904044432),
#  ('instincts', 0.8383291904044432),
#  ('otto', 0.8383291904044432),
#  ('adventure', 0.83797812843840136),
#  ('dancer', 0.83772840937105286),
#  ('strength', 0.83759846329849019),
#  ('tight', 0.83685390122612036),
#  ('explicit', 0.83532166934048779),
#  ('straightforward', 0.83479769762297218),
#  ('servant', 0.83479769762297218),
#  ('teaches', 0.83479769762297218),
#  ('adds', 0.83461270085988781),
#  ('carl', 0.83422577881985094),
#  ('surreal', 0.83359901602904163),
#  ('miike', 0.83290912293510388),
#  ('feat', 0.83290912293510388),
#  ('dudley', 0.83290912293510388),
#  ('wax', 0.83290912293510388),
#  ('childhood', 0.83129751904076243),
#  ('delighted', 0.83034830207343024),
#  ('studios', 0.82894872171900713),
#  ('con', 0.82894872171900713),
#  ('dances', 0.8286926725561693),
#  ('abc', 0.82832195892819782),
#  ('kurt', 0.8280664984593159),
#  ('eyre', 0.82667857318446791),
#  ('paintings', 0.82667857318446791),
#  ('antonioni', 0.82417544296634937),
#  ('separated', 0.8232003088081431),
#  ('offbeat', 0.8232003088081431),
#  ('astounding', 0.8232003088081431),
#  ('principle', 0.8232003088081431),
#  ('develops', 0.82098055206983034),
#  ('waters', 0.82098055206983034),
#  ('shares', 0.82098055206983034),
#  ('conventions', 0.82098055206983034),
#  ('sides', 0.82014687132125286),
#  ('touches', 0.81970990386837461),
#  ('importance', 0.81902742644894799),
#  ('oscars', 0.81831032351395128),
#  ('disappoint', 0.81831032351395128),
#  ('traditional', 0.81793795337373354),
#  ('deals', 0.81793795337373354),
#  ('empire', 0.8167611365271219),
#  ('scarface', 0.8167611365271219),
#  ('des', 0.8167611365271219),
#  ('holds', 0.81574950265227764),
#  ('shared', 0.81574950265227764),
#  ('boxer', 0.81574950265227764),
#  ('attenborough', 0.81574950265227764),
#  ('albert', 0.81503699816898212),
#  ('gene', 0.81484411553746505),
#  ('backgrounds', 0.81450803756421286),
#  ('matches', 0.81450803756421286),
#  ('styles', 0.81409979097760776),
#  ('daring', 0.81409979097760776),
#  ('legendary', 0.81281168431603446),
#  ('realistic', 0.8123598090259232),
#  ('desires', 0.81093021621632877),
#  ('truths', 0.81093021621632877),
#  ('stern', 0.81093021621632877),
#  ('hearted', 0.80931861232198732),
#  ('sentimental', 0.80845802707093972),
#  ('cry', 0.80821651034473263),
#  ('portraying', 0.80775056329894912),
#  ('environment', 0.80680649903246682),
#  ('gothic', 0.80562516398663564),
#  ('marries', 0.80562516398663564),
#  ('commitment', 0.80437281567016972),
#  ('realization', 0.80437281567016972),
#  ('tense', 0.80381274844746464),
#  ('achieved', 0.80314807577427383),
#  ('impressed', 0.80171356111140479),
#  ('stages', 0.80077784475231062),
#  ('boston', 0.80077784475231062),
#  ('forms', 0.80011930011211307),
#  ('captured', 0.79850769621777162),
#  ('rooney', 0.79850769621777162),
#  ('classy', 0.79850769621777162),
#  ('toby', 0.79850769621777162),
#  ('jean', 0.79758984392754273),
#  ('edge', 0.79704677557809678),
#  ('sharp', 0.79694397424158891),
#  ('court', 0.79600456599965308),
#  ('covers', 0.79492987486988764),
#  ('reunion', 0.79424329743131417),
#  ('steals', 0.79395187968191083),
#  ('blob', 0.79323063911692793),
#  ('colors', 0.79284654078303329),
#  ('rules', 0.79223808320417632),
#  ('sung', 0.79223808320417632),
#  ('conventional', 0.79112758892014912),
#  ('denzel', 0.79052134458512169),
#  ('frank', 0.78972800856572589),
#  ('museum', 0.78845736036427028),
#  ('aids', 0.78845736036427028),
#  ('comfort', 0.78845736036427028),
#  ('nations', 0.78845736036427028),
#  ('landscape', 0.78592891401091158),
#  ('testament', 0.78495472981306824),
#  ('attend', 0.78495472981306824),
#  ('rain', 0.78411895876567206),
#  ('bondage', 0.78411895876567206),
#  ('immensely', 0.78275933924963248),
#  ('obstacles', 0.78275933924963248),
#  ('enigmatic', 0.78275933924963248),
#  ('dominic', 0.78275933924963248),
#  ('seeks', 0.78170057790139036),
#  ('domestic', 0.78170057790139036),
#  ('maria', 0.78015855754957497),
#  ('difficulty', 0.78015855754957497),
#  ('spring', 0.77908961036066993),
#  ('cagney', 0.77908961036066993),
#  ('midnight', 0.77866935399810722),
#  ('remembers', 0.77770456858800829),
#  ('document', 0.77770456858800829),
#  ('strict', 0.77770456858800829),
#  ('anthology', 0.77770456858800829),
#  ('stays', 0.77652878949899629),
#  ('christine', 0.77652878949899629),
#  ('tale', 0.77411624309361238),
#  ('titanic', 0.77318988823348167),
#  ('sunday', 0.77318988823348167),
#  ('unfold', 0.77318988823348167),
#  ('intricate', 0.77318988823348167),
#  ('fathers', 0.77010822169607374),
#  ('fresh', 0.76995259178369035),
#  ('bruno', 0.76913308753786735),
#  ('magician', 0.76913308753786735),
#  ('sir', 0.76787072675588186),
#  ('retired', 0.76725515271366718),
#  ('nowadays', 0.76590653484237359),
#  ('kent', 0.76546784213957142),
#  ('polished', 0.76460614454209042),
#  ('willie', 0.76460614454209042),
#  ('influenced', 0.76409891653222972),
#  ('florida', 0.76409891653222972),
#  ('nevertheless', 0.76391625144815245),
#  ('animated', 0.76376474777389869),
#  ('leslie', 0.76335143923319382),
#  ('driven', 0.76301686052043127),
#  ('knightley', 0.76214005204689672),
#  ('packed', 0.76080582903376015),
#  ('strikes', 0.76058846135547775),
#  ('secretary', 0.7591051483517427),
#  ('casual', 0.7591051483517427),
#  ('slimy', 0.7591051483517427),
#  ('memories', 0.7583877024283463),
#  ('golden', 0.75730912477723111),
#  ('che', 0.75722603724446769),
#  ('provoking', 0.75709590516021885),
#  ('elderly', 0.75686299494605314),
#  ('prejudice', 0.75632608218147701),
#  ('enjoyable', 0.7561743371129005),
#  ('lovers', 0.75566753754127924),
#  ('faults', 0.75566753754127924),
#  ('depiction', 0.75484074956528524),
#  ('blues', 0.7537718023763802),
#  ('frances', 0.7537718023763802),
#  ('trek', 0.75233605195027597),
#  ('performances', 0.75054338956426092),
#  ('controlling', 0.75030559439989397),
#  ('clerk', 0.75030559439989397),
#  ('moss', 0.75030559439989397),
#  ('simple', 0.74945835212266076),
#  ('relationship', 0.74806293815605995),
#  ('bears', 0.74721440183022114),
#  ('whoopi', 0.74721440183022114),
#  ('showdown', 0.74721440183022114),
#  ('album', 0.74721440183022114),
#  ('cutter', 0.74721440183022114),
#  ('supporting', 0.7470322690549247),
#  ('germany', 0.74649316126523801),
#  ('verhoeven', 0.74444047494749577),
#  ('victorian', 0.74444047494749577),
#  ('readers', 0.74444047494749577),
#  ('glued', 0.74444047494749577),
#  ('advanced', 0.74357803418683721),
#  ('bugs', 0.74290869011900906),
#  ('lewis', 0.74247224712244675),
#  ('waves', 0.74193734472937733),
#  ('affects', 0.74193734472937733),
#  ('hugely', 0.74193734472937733),
#  ('ingrid', 0.74193734472937733),
#  ('emotional', 0.74148800749422783),
#  ('china', 0.74115639974630598),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.962844630259907),
#  ('uwe', -4.6151205168412597),
#  ('thunderbirds', -4.1108738641733114),
#  ('beowulf', -4.0943445622221004),
#  ('dahmer', -3.970291913552122),
#  ('wayans', -3.912023005428146),
#  ('seagal', -3.6375861597263857),
#  ('gamera', -3.3141860046725258),
#  ('dreck', -3.2580965380214821),
#  ('unwatchable', -3.2484346271097451),
#  ('stinker', -3.1986731175506815),
#  ('mst', -2.9444389791664407),
#  ('incoherent', -2.9292871741458382),
#  ('flimsy', -2.9087208965643612),
#  ('dillinger', -2.8134107167600364),
#  ('yawn', -2.8033603809065348),
#  ('unfunny', -2.6882475738060303),
#  ('waste', -2.6186484579840514),
#  ('ugh', -2.6026896854443837),
#  ('turd', -2.6026896854443837),
#  ('blah', -2.5649493574615367),
#  ('slugs', -2.5455312716044354),
#  ('tripe', -2.4849066497880004),
#  ('horrid', -2.4756042571256867),
#  ('wtf', -2.4680995314716192),
#  ('pointless', -2.4531579514734201),
#  ('atrocious', -2.4203681286504293),
#  ('damme', -2.3978952727983707),
#  ('redeeming', -2.3648889763302003),
#  ('prom', -2.3513752571634776)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1,vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'clich': 1,
#  'ofr': 2,
#  'willims': 3,
#  'dey': 4,
#  'jabbering': 5,
#  'pronouncing': 6,
#  'aforementioned': 7,
#  'preminger': 8,
#  'kanoodling': 9,
#  'sovsem': 10,
#  'hacen': 11,
#  'dispised': 12,
#  'derita': 13,
#  'swollen': 14,
#  'anycase': 15,
#  'multinationals': 16,
#  'seriesall': 17,
#  'workforces': 18,
#  'pasolini': 19,
#  'lounge': 20,
#  'wash': 21,
#  'bunnie': 22,
#  'ungureanu': 23,
#  'lovers': 24,
#  'viard': 25,
#  'crapola': 26,
#  'manheim': 27,
#  'heavenward': 28,
#  'suman': 29,
#  'jhene': 30,
#  'blissfully': 31,
#  'apprenticeship': 32,
#  'sneezing': 33,
#  'mountains': 34,
#  'wealthier': 35,
#  'sandhya': 36,
#  'tuggee': 37,
#  'militarist': 38,
#  'sag': 39,
#  'sol': 40,
#  'faggot': 41,
#  'telepathically': 42,
#  'mwahaha': 43,
#  'barracks': 44,
#  'blackfriars': 45,
#  'successive': 46,
#  'maggie': 47,
#  'puny': 48,
#  'lively': 49,
#  'sarongs': 50,
#  'male': 51,
#  'aborigone': 52,
#  'identified': 53,
#  'oz': 54,
#  'deodato': 55,
#  'cheerless': 56,
#  'dickens': 57,
#  'unopened': 58,
#  'messaging': 59,
#  'diabolists': 60,
#  'psychologists': 61,
#  'ouroboros': 62,
#  'hamlisch': 63,
#  'superhuman': 64,
#  'fruitless': 65,
#  'ignominiously': 66,
#  'topnotch': 67,
#  'subdue': 68,
#  'stages': 69,
#  'crudy': 70,
#  'flavour': 71,
#  'resi': 72,
#  'fringe': 73,
#  'rawanda': 74,
#  'impotency': 75,
#  'perseverence': 76,
#  'wipes': 77,
#  'oddest': 78,
#  'bleeder': 79,
#  'mostfamous': 80,
#  'mmm': 81,
#  'staffenberg': 82,
#  'upatz': 83,
#  'naustradamous': 84,
#  'parfait': 85,
#  'heyward': 86,
#  'lazy': 87,
#  'rohal': 88,
#  'megalomanous': 89,
#  'sellick': 90,
#  'simmering': 91,
#  'sleuth': 92,
#  'outfitted': 93,
#  'schwimmer': 94,
#  'dunlay': 95,
#  'busybody': 96,
#  'updyke': 97,
#  'gruver': 98,
#  'marriott': 99,
#  'tramonti': 100,
#  'healthy': 101,
#  'castelnuovo': 102,
#  'mistake': 103,
#  'holes': 104,
#  'ragtag': 105,
#  'frederick': 106,
#  'im': 107,
#  'seagoing': 108,
#  'araki': 109,
#  'demeaned': 110,
#  'dell': 111,
#  'jonas': 112,
#  'padme': 113,
#  'corks': 114,
#  'prepares': 115,
#  'gladiator': 116,
#  'oscar': 117,
#  'glacial': 118,
#  'armament': 119,
#  'hadith': 120,
#  'noisily': 121,
#  'headroom': 122,
#  'subiaco': 123,
#  'clacks': 124,
#  'postings': 125,
#  'clairvoyance': 126,
#  'songbook': 127,
#  'unite': 128,
#  'pinciotti': 129,
#  'filmmmakers': 130,
#  'giligan': 131,
#  'ladislas': 132,
#  'performancein': 133,
#  'garbo': 134,
#  'scorecard': 135,
#  'abducting': 136,
#  'ignites': 137,
#  'slumber': 138,
#  'transformations': 139,
#  'ricki': 140,
#  'aire': 141,
#  'joey': 142,
#  'leo': 143,
#  'philosophically': 144,
#  'terrorizer': 145,
#  'moan': 146,
#  'aware': 147,
#  'doyon': 148,
#  'drips': 149,
#  'understudies': 150,
#  'reguritated': 151,
#  'graham': 152,
#  'dkman': 153,
#  'withdrawal': 154,
#  'legde': 155,
#  'etta': 156,
#  'preproduction': 157,
#  'mistiness': 158,
#  'glanced': 159,
#  'palpably': 160,
#  'nath': 161,
#  'bulging': 162,
#  'carreyed': 163,
#  'lawnmowers': 164,
#  'orpheus': 165,
#  'trap': 166,
#  'ensor': 167,
#  'celina': 168,
#  'yarding': 169,
#  'kleinschloss': 170,
#  'higuchi': 171,
#  'lh': 172,
#  'jerilderie': 173,
#  'manette': 174,
#  'hamil': 175,
#  'cosimo': 176,
#  'excused': 177,
#  'reallllllllly': 178,
#  'austen': 179,
#  'fungal': 180,
#  'reactivation': 181,
#  'farrellys': 182,
#  'raposo': 183,
#  'marlowe': 184,
#  'dramatizing': 185,
#  'beringer': 186,
#  'grizzly': 187,
#  'quarreling': 188,
#  'segregating': 189,
#  'ritualized': 190,
#  'hat': 191,
#  'morocco': 192,
#  'significances': 193,
#  'gas': 194,
#  'softener': 195,
#  'emek': 196,
#  'compendium': 197,
#  'dukakis': 198,
#  'bread': 199,
#  'kneed': 200,
#  'numbs': 201,
#  'findlay': 202,
#  'g': 203,
#  'baccarin': 204,
#  'submerged': 205,
#  'lusts': 206,
#  'ishiro': 207,
#  'uncompromizing': 208,
#  'dyad': 209,
#  'ranger': 210,
#  'droll': 211,
#  'dint': 212,
#  'reeking': 213,
#  'czechs': 214,
#  'bice': 215,
#  'bystanders': 216,
#  'verit': 217,
#  'islamic': 218,
#  'predilections': 219,
#  'yasushi': 220,
#  'vestige': 221,
#  'dalliances': 222,
#  'akte': 223,
#  'imbred': 224,
#  'dangled': 225,
#  'hb': 226,
#  'daggy': 227,
#  'abyss': 228,
#  'ohmigod': 229,
#  'usb': 230,
#  'swords': 231,
#  'holcomb': 232,
#  'blane': 233,
#  'lattes': 234,
#  'chakra': 235,
#  'wickes': 236,
#  'shipped': 237,
#  'growling': 238,
#  'rekha': 239,
#  'callum': 240,
#  'slush': 241,
#  'waco': 242,
#  'rolleball': 243,
#  'ludicrousness': 244,
#  'kascier': 245,
#  'lindo': 246,
#  'matchup': 247,
#  'referred': 248,
#  'fdr': 249,
#  'crudely': 250,
#  'movieand': 251,
#  'aggravating': 252,
#  'fixed': 253,
#  'laxative': 254,
#  'lighted': 255,
#  'bazookas': 256,
#  'magnavision': 257,
#  'barest': 258,
#  'lunatic': 259,
#  'inner': 260,
#  'tink': 261,
#  'parisienne': 262,
#  'sidestepped': 263,
#  'hagiography': 264,
#  'waalkes': 265,
#  'honhyol': 266,
#  'installments': 267,
#  'newsreel': 268,
#  'cus': 269,
#  'mutual': 270,
#  'fanaticism': 271,
#  'patches': 272,
#  'vooren': 273,
#  'oceanography': 274,
#  'hispano': 275,
#  'invesment': 276,
#  'deprecating': 277,
#  'degenerated': 278,
#  'righting': 279,
#  'dorky': 280,
#  'guignol': 281,
#  'percept': 282,
#  'pervious': 283,
#  'tgif': 284,
#  'queensbury': 285,
#  'erosion': 286,
#  'deliverly': 287,
#  'dearest': 288,
#  'sobers': 289,
#  'bethlehem': 290,
#  'momsem': 291,
#  'blurts': 292,
#  'cronenberg': 293,
#  'filmschool': 294,
#  'yeeeeaaaaahhhhhhhhh': 295,
#  'limo': 296,
#  'niggles': 297,
#  'affect': 298,
#  'crewmemebers': 299,
#  'themself': 300,
#  'raymonde': 301,
#  'necklace': 302,
#  'modulated': 303,
#  'contrastingly': 304,
#  'greer': 305,
#  'amithab': 306,
#  'motor': 307,
#  'kittenishly': 308,
#  'edina': 309,
#  'elusive': 310,
#  'micmac': 311,
#  'slams': 312,
#  'calves': 313,
#  'solidarity': 314,
#  'lawnmower': 315,
#  'dohhh': 316,
#  'gamut': 317,
#  'griever': 318,
#  'biswas': 319,
#  'mediation': 320,
#  'yousef': 321,
#  'dizzyingly': 322,
#  'resurrections': 323,
#  'cringingly': 324,
#  'nachtgestalten': 325,
#  'regan': 326,
#  'irishman': 327,
#  'dock': 328,
#  'tokens': 329,
#  'independents': 330,
#  'newgrounds': 331,
#  'weekends': 332,
#  'termination': 333,
#  'unaffected': 334,
#  'additives': 335,
#  'notches': 336,
#  'peeking': 337,
#  'melissa': 338,
#  'mongols': 339,
#  'kursk': 340,
#  'fcc': 341,
#  'crypton': 342,
#  'taxi': 343,
#  'nechayev': 344,
#  'unmemorable': 345,
#  'preferably': 346,
#  'manifested': 347,
#  'bucharest': 348,
#  'approporiately': 349,
#  'mciver': 350,
#  'maki': 351,
#  'harbored': 352,
#  'stables': 353,
#  'bourn': 354,
#  'zucchini': 355,
#  'malformations': 356,
#  'fixes': 357,
#  'buttered': 358,
#  'scarecrows': 359,
#  'boringlane': 360,
#  'skeptically': 361,
#  'gertrdix': 362,
#  'brims': 363,
#  'caffeine': 364,
#  'myrtile': 365,
#  'trouts': 366,
#  'astoria': 367,
#  'regards': 368,
#  'flyte': 369,
#  'capable': 370,
#  'kutcher': 371,
#  'noltie': 372,
#  'geopolitical': 373,
#  'cussack': 374,
#  'mila': 375,
#  'invalidity': 376,
#  'teague': 377,
#  'postdates': 378,
#  'cranked': 379,
#  'sparklers': 380,
#  'paluzzi': 381,
#  'sewn': 382,
#  'saarsgard': 383,
#  'swooningly': 384,
#  'depend': 385,
#  'pulverized': 386,
#  'kens': 387,
#  'knitting': 388,
#  'inked': 389,
#  'doddering': 390,
#  'spain': 391,
#  'doss': 392,
#  'incorporating': 393,
#  'dilated': 394,
#  'corpsethe': 395,
#  'tahitian': 396,
#  'dedication': 397,
#  'ke': 398,
#  'disrupts': 399,
#  'lawsuits': 400,
#  'accidents': 401,
#  'panabaker': 402,
#  'hatsumo': 403,
#  'offside': 404,
#  'kiesche': 405,
#  'succumb': 406,
#  'storyplot': 407,
#  'torchy': 408,
#  'akiva': 409,
#  'beeped': 410,
#  'reognise': 411,
#  'vertiginous': 412,
#  'headmaster': 413,
#  'resent': 414,
#  'shaye': 415,
#  'paraphrased': 416,
#  'catastrophic': 417,
#  'evolve': 418,
#  'churidar': 419,
#  'manhole': 420,
#  'payers': 421,
#  'husbands': 422,
#  'sponsor': 423,
#  'barbedwire': 424,
#  'dexterity': 425,
#  'inclusiveness': 426,
#  'devote': 427,
#  'villaness': 428,
#  'foxley': 429,
#  'wolliaston': 430,
#  'trudie': 431,
#  'numerous': 432,
#  'tragedies': 433,
#  'purest': 434,
#  'ryo': 435,
#  'etcetera': 436,
#  'opens': 437,
#  'morteval': 438,
#  'befriends': 439,
#  'controversial': 440,
#  'piracy': 441,
#  'yes': 442,
#  'thatch': 443,
#  'divisions': 444,
#  'capucines': 445,
#  'canvas': 446,
#  'feign': 447,
#  'comin': 448,
#  'seyrig': 449,
#  'radiations': 450,
#  'spartans': 451,
#  'tramples': 452,
#  'luiz': 453,
#  'elected': 454,
#  'illinois': 455,
#  'lifeforce': 456,
#  'clevon': 457,
#  'sasqu': 458,
#  'practicable': 459,
#  'jpdutta': 460,
#  'downsides': 461,
#  'heah': 462,
#  'looted': 463,
#  'falsifying': 464,
#  'tiw': 465,
#  'voice': 466,
#  'liners': 467,
#  'mela': 468,
#  'despises': 469,
#  'denunciation': 470,
#  'woofer': 471,
#  'marches': 472,
#  'judging': 473,
#  'variable': 474,
#  'gialli': 475,
#  'paperboy': 476,
#  'satred': 477,
#  'junked': 478,
#  'thx': 479,
#  'deflowers': 480,
#  'reprint': 481,
#  'emissary': 482,
#  'draped': 483,
#  'obedience': 484,
#  'kinetescope': 485,
#  'textural': 486,
#  'drifters': 487,
#  'mass': 488,
#  'qi': 489,
#  'inbetween': 490,
#  'rispoli': 491,
#  'lucrative': 492,
#  'mariette': 493,
#  'firms': 494,
#  'aroona': 495,
#  'tamale': 496,
#  'phaoroh': 497,
#  'birtwhistle': 498,
#  'introductory': 499,
#  'insinuation': 500,
#  'unemployed': 501,
#  'disowning': 502,
#  'hiroshi': 503,
#  'artemisia': 504,
#  'sleaziness': 505,
#  'bridging': 506,
#  'glimse': 507,
#  'artistry': 508,
#  'clingy': 509,
#  'mccormick': 510,
#  'gabin': 511,
#  'moping': 512,
#  'guttenburg': 513,
#  'undistilled': 514,
#  'devotee': 515,
#  'misadventure': 516,
#  'rosamunde': 517,
#  'pepperday': 518,
#  'devotes': 519,
#  'displayed': 520,
#  'wows': 521,
#  'masssacre': 522,
#  'gta': 523,
#  'chomsky': 524,
#  'orville': 525,
#  'hylands': 526,
#  'enchantingly': 527,
#  'malade': 528,
#  'hearp': 529,
#  'stilted': 530,
#  'blooper': 531,
#  'fn': 532,
#  'jens': 533,
#  'naudets': 534,
#  'elogious': 535,
#  'dodged': 536,
#  'viertel': 537,
#  'jokester': 538,
#  'puerility': 539,
#  'dja': 540,
#  'smells': 541,
#  'complements': 542,
#  'artisans': 543,
#  'scribes': 544,
#  'propagate': 545,
#  'dorthy': 546,
#  'leporidae': 547,
#  'davidians': 548,
#  'remick': 549,
#  'teddy': 550,
#  'oozes': 551,
#  'oakland': 552,
#  'archetype': 553,
#  'prescient': 554,
#  'chicken': 555,
#  'steadicam': 556,
#  'indoors': 557,
#  'zazu': 558,
#  'brune': 559,
#  'miamis': 560,
#  'flubs': 561,
#  'luise': 562,
#  'conventional': 563,
#  'belittles': 564,
#  'cusack': 565,
#  'tron': 566,
#  'nicknames': 567,
#  'critique': 568,
#  'vigo': 569,
#  'wilting': 570,
#  'maximum': 571,
#  'apartheid': 572,
#  'intuitive': 573,
#  'refunded': 574,
#  'dissemination': 575,
#  'vendetta': 576,
#  'crowne': 577,
#  'khazzan': 578,
#  'uk': 579,
#  'nicked': 580,
#  'swathe': 581,
#  'simplebut': 582,
#  'ducts': 583,
#  'magilla': 584,
#  'koster': 585,
#  'wrassle': 586,
#  'cake': 587,
#  'begin': 588,
#  'nanette': 589,
#  'motivates': 590,
#  'cheeses': 591,
#  'social': 592,
#  'knopfler': 593,
#  'eccentricity': 594,
#  'tyson': 595,
#  'admonishes': 596,
#  'savier': 597,
#  'stimulating': 598,
#  'understandings': 599,
#  'roald': 600,
#  'bohnen': 601,
#  'spacek': 602,
#  'botega': 603,
#  'tendulkar': 604,
#  'havana': 605,
#  'jewish': 606,
#  'slippery': 607,
#  'megessey': 608,
#  'abhijeet': 609,
#  'thurber': 610,
#  'pianos': 611,
#  'hums': 612,
#  'posting': 613,
#  'deem': 614,
#  'townsfolk': 615,
#  'impelled': 616,
#  'kosturica': 617,
#  'panamericano': 618,
#  'intensely': 619,
#  'rages': 620,
#  'copywriter': 621,
#  'affectionate': 622,
#  'butterfly': 623,
#  'hassan': 624,
#  'seigner': 625,
#  'arisen': 626,
#  'hollywoodized': 627,
#  'trixie': 628,
#  'stoical': 629,
#  'jalouse': 630,
#  'resonates': 631,
#  'salivate': 632,
#  'peng': 633,
#  'caption': 634,
#  'barboo': 635,
#  'loftier': 636,
#  'acknowledgment': 637,
#  'cage': 638,
#  'filmakers': 639,
#  'kaajal': 640,
#  'dreamworld': 641,
#  'geeson': 642,
#  'samstag': 643,
#  'hayne': 644,
#  'astounded': 645,
#  'aclu': 646,
#  'windlass': 647,
#  'creatively': 648,
#  'rumbles': 649,
#  'lughnasa': 650,
#  'lamore': 651,
#  'outshoot': 652,
#  'impromptu': 653,
#  'parenting': 654,
#  'airheaded': 655,
#  'valuables': 656,
#  'gassy': 657,
#  'compete': 658,
#  'apparently': 659,
#  'sturges': 660,
#  'herder': 661,
#  'resoundingly': 662,
#  'wearied': 663,
#  'angelwas': 664,
#  'brusk': 665,
#  'piena': 666,
#  'advocacy': 667,
#  'dungeon': 668,
#  'tonne': 669,
#  'trubshawe': 670,
#  'dummy': 671,
#  'varieties': 672,
#  'limpid': 673,
#  'lampidorrans': 674,
#  'lue': 675,
#  'housekeeping': 676,
#  'sandrelli': 677,
#  'ridge': 678,
#  'ruled': 679,
#  'kotex': 680,
#  'alfonso': 681,
#  'leartes': 682,
#  'launches': 683,
#  'lofty': 684,
#  'karlsson': 685,
#  'choral': 686,
#  'eggert': 687,
#  'humblest': 688,
#  'storyville': 689,
#  'apologia': 690,
#  'rostenberg': 691,
#  'nosebleed': 692,
#  'submarines': 693,
#  'soapy': 694,
#  'holwing': 695,
#  'dreamscape': 696,
#  'hellbored': 697,
#  'schilling': 698,
#  'beatles': 699,
#  'expertly': 700,
#  'livien': 701,
#  'honourable': 702,
#  'blackbelts': 703,
#  'horniness': 704,
#  'pamby': 705,
#  'yeh': 706,
#  'charlies': 707,
#  'resistor': 708,
#  'insubordinate': 709,
#  'avg': 710,
#  'bride': 711,
#  'salary': 712,
#  'uhm': 713,
#  'chrissie': 714,
#  'amnesic': 715,
#  'panning': 716,
#  'plunging': 717,
#  'videoasia': 718,
#  'dissocial': 719,
#  'doeesn': 720,
#  'tamped': 721,
#  'weclome': 722,
#  'tratment': 723,
#  'fulbright': 724,
#  'proportionately': 725,
#  'explorations': 726,
#  'yez': 727,
#  'bigardo': 728,
#  'expertjewelry': 729,
#  'kinematograph': 730,
#  'stringy': 731,
#  'fastidiously': 732,
#  'preservation': 733,
#  'inappreciable': 734,
#  'reproduce': 735,
#  'donlon': 736,
#  'lyin': 737,
#  'gretel': 738,
#  'contemporary': 739,
#  'verb': 740,
#  'toni': 741,
#  'lord': 742,
#  'aboriginies': 743,
#  'deferent': 744,
#  'battleships': 745,
#  'chimpanzees': 746,
#  'expensive': 747,
#  'cabby': 748,
#  'daleks': 749,
#  'infesting': 750,
#  'dissing': 751,
#  'burtonesque': 752,
#  'sherlock': 753,
#  'fatcheek': 754,
#  'convection': 755,
#  'crushes': 756,
#  'crusade': 757,
#  'soavi': 758,
#  'amer': 759,
#  'lowlifes': 760,
#  'mesmerised': 761,
#  'sherlyn': 762,
#  'copyrights': 763,
#  'formally': 764,
#  'mclarty': 765,
#  'hunchbacked': 766,
#  'cheoreography': 767,
#  'andorra': 768,
#  'mcduck': 769,
#  'rebroadcast': 770,
#  'tonnerre': 771,
#  'metaphysics': 772,
#  'fishhooks': 773,
#  'blacking': 774,
#  'timed': 775,
#  'mcc': 776,
#  'velde': 777,
#  'learned': 778,
#  'oakie': 779,
#  'goofus': 780,
#  'maelstrom': 781,
#  'garter': 782,
#  'clings': 783,
#  'naval': 784,
#  'tuskegee': 785,
#  'nb': 786,
#  'hebrew': 787,
#  'brigand': 788,
#  'bejing': 789,
#  'whitley': 790,
#  'duryea': 791,
#  'stirred': 792,
#  'kammerud': 793,
#  'duchess': 794,
#  'mainly': 795,
#  'moranis': 796,
#  'filmfour': 797,
#  'disrobing': 798,
#  'spray': 799,
#  'smidgeon': 800,
#  'seal': 801,
#  'blueprint': 802,
#  'overboard': 803,
#  'phonus': 804,
#  'mulrony': 805,
#  'lug': 806,
#  'bravo': 807,
#  'martinaud': 808,
#  'improvisations': 809,
#  'gyrating': 810,
#  'mareno': 811,
#  'awstruck': 812,
#  'winkelman': 813,
#  'acadamy': 814,
#  'oedipal': 815,
#  'tudor': 816,
#  'mcgoldrick': 817,
#  'documentaries': 818,
#  'fminin': 819,
#  'wheeeew': 820,
#  'zoologist': 821,
#  'neha': 822,
#  'penal': 823,
#  'satirizing': 824,
#  'monkey': 825,
#  'nevermind': 826,
#  'heisthostage': 827,
#  'lorica': 828,
#  'occassionaly': 829,
#  'academies': 830,
#  'loffe': 831,
#  'policewomen': 832,
#  'footpaths': 833,
#  'allright': 834,
#  'uterus': 835,
#  'melds': 836,
#  'together': 837,
#  'metamorphose': 838,
#  'xxxxviii': 839,
#  'alums': 840,
#  'christo': 841,
#  'ue': 842,
#  'ponderously': 843,
#  'exciter': 844,
#  'woulnd': 845,
#  'livening': 846,
#  'terrence': 847,
#  'grin': 848,
#  'eschewing': 849,
#  'precept': 850,
#  'teenth': 851,
#  'compelling': 852,
#  'scapinelli': 853,
#  'earned': 854,
#  'assignation': 855,
#  'potently': 856,
#  'too': 857,
#  'scape': 858,
#  'hugwagon': 859,
#  'theatregoers': 860,
#  'chowdhry': 861,
#  'lindsay': 862,
#  'outliving': 863,
#  'argonne': 864,
#  'distrust': 865,
#  'teen': 866,
#  'stacked': 867,
#  'fallwell': 868,
#  'antoni': 869,
#  'blackface': 870,
#  'mohandas': 871,
#  'buschemi': 872,
#  'rene': 873,
#  'chefs': 874,
#  'steeped': 875,
#  'gracias': 876,
#  'backer': 877,
#  'voyeur': 878,
#  'bullosa': 879,
#  'luz': 880,
#  'potboilers': 881,
#  'sensitively': 882,
#  'oopps': 883,
#  'barem': 884,
#  'arther': 885,
#  'cassella': 886,
#  'lupus': 887,
#  'styler': 888,
#  'primo': 889,
#  'skims': 890,
#  'andi': 891,
#  'javerts': 892,
#  'miscarriages': 893,
#  'stedicam': 894,
#  'gnash': 895,
#  'scribbling': 896,
#  'tiene': 897,
#  'tusks': 898,
#  'lenient': 899,
#  'hikes': 900,
#  'snobbishness': 901,
#  'segments': 902,
#  'morphs': 903,
#  'doctored': 904,
#  'sht': 905,
#  'deposited': 906,
#  'parhat': 907,
#  'hellfire': 908,
#  'evaporated': 909,
#  'yeung': 910,
#  'performaces': 911,
#  'varying': 912,
#  'fuhgeddaboudit': 913,
#  'striven': 914,
#  'neighbourhoods': 915,
#  'teamups': 916,
#  'frats': 917,
#  'helm': 918,
#  'bachmann': 919,
#  'terminus': 920,
#  'sung': 921,
#  'oldsmobile': 922,
#  'somme': 923,
#  'retrieves': 924,
#  'profiles': 925,
#  'microcosmos': 926,
#  'coronation': 927,
#  'catharsic': 928,
#  'hitching': 929,
#  'scion': 930,
#  'aroused': 931,
#  'levinson': 932,
#  'scooping': 933,
#  'shelli': 934,
#  'yore': 935,
#  'boiler': 936,
#  'adjani': 937,
#  'pl': 938,
#  'bins': 939,
#  'vetting': 940,
#  'surveyed': 941,
#  'woolnough': 942,
#  'ahead': 943,
#  'doorways': 944,
#  'munsters': 945,
#  'earthly': 946,
#  'richards': 947,
#  'wheels': 948,
#  'dashiell': 949,
#  'deformity': 950,
#  'perished': 951,
#  'falak': 952,
#  'kidulthood': 953,
#  'notte': 954,
#  'envisions': 955,
#  'hardship': 956,
#  'resourcecenter': 957,
#  'ablaze': 958,
#  'unbelievability': 959,
#  'bassist': 960,
#  'watsoever': 961,
#  'prevert': 962,
#  'reprints': 963,
#  'directory': 964,
#  'christers': 965,
#  'dogtown': 966,
#  'planetoids': 967,
#  'brants': 968,
#  'shipbuilder': 969,
#  'bing': 970,
#  'katsopolis': 971,
#  'nonlds': 972,
#  'fetches': 973,
#  'visibile': 974,
#  'krel': 975,
#  'ireland': 976,
#  'ingenuous': 977,
#  'subplots': 978,
#  'regimes': 979,
#  'poehler': 980,
#  'vicotria': 981,
#  'morolla': 982,
#  'diavolo': 983,
#  'survive': 984,
#  'opioion': 985,
#  'golfer': 986,
#  'mccomb': 987,
#  'flores': 988,
#  'troubled': 989,
#  'witchboard': 990,
#  'discoverer': 991,
#  'showy': 992,
#  'panitz': 993,
#  'ventures': 994,
#  'intermittedly': 995,
#  'railways': 996,
#  'denice': 997,
#  'missie': 998,
#  'tortuously': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for w in review.split(' '):
        layer_0[0][word2index[w]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    return int(label == "POSITIVE")

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        vocab = []
        for r in reviews:
            vocab += r.split(' ')
        review_vocab = set(vocab)
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set(labels)
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for i,w in enumerate(self.review_vocab):
            self.word2index[w] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for i,w in enumerate(self.review_vocab):
            self.word2index[w] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.zeros((self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0

        # TODO: count how many times each word is used in the given review and store the results in layer_0 
        for w in review.split(' '):
            self.layer_0[0][word2index[w]] += 1
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        return int(label == "POSITIVE")
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return sigmoid(output) * (1 - output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            y = get_target_for_label(training_labels[i])
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            update_input_layer(review)
            hidden_input = np.dot(self.layer_0, self.weights_0_1)
            hidden_output = hidden_input
            
            final_input = np.dot(hidden_output, self.weights_1_2)
            final_output = sigmoid(final_input)
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            error = y - final_output
            error_term = error * sigmoid_output_2_derivative(final_output)
            
            hidden_error = np.dot(error_term, self.weights_1_2)
            hidden_error_term = hidden_error
            
            delta_1_0 = np.dot(error_term, hidden_output)
            delta_0_1 = np.dot(error_term, self.layer_0)
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            if error < .5:
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.

        # TODO: Implement the forward pass through the network. 
        #       That means use the given review to update the input layer, 
        #       then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        # 
        #       Do not use an activation function for the hidden layer,
        #       but use the sigmoid activation function for the output layer.
        update_input_layer(review)
        hidden_input = np.dot(self.layer_0, self.weights_0_1)
        hidden_output = hidden_input

        final_input = np.dot(hidden_output, self.weights_1_2)
        final_output = self.sigmoid(final_input)
        
        if final_output > .5:
            return 'POSITIVE'
        else:
            return 'NEGATIVE'

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-a1814268d45c> in <module>()
# ----> 1 mlp.test(reviews[-1000:],labels[-1000:])
#
# <ipython-input-125-fdfc51c00a14> in test(self, testing_reviews, testing_labels)
#     197         # its label.
#     198         for i in range(len(testing_reviews)):
# --> 199             pred = self.run(testing_reviews[i])
#     200             if(pred == testing_labels[i]):
#     201                 correct += 1
#
# <ipython-input-125-fdfc51c00a14> in run(self, review)
#     233         #       Do not use an activation function for the hidden layer,
#     234         #       but use the sigmoid activation function for the output layer.
# --> 235         self.update_input_layer(review)
#     236         hidden_input = np.dot(self.layer_0, self.weights_0_1)
#     237         hidden_output = hidden_input
#
# <ipython-input-125-fdfc51c00a14> in update_input_layer(self, review)
#     102         # TODO: count how many times each word is used in the given review and store the results in layer_0
#     103         for w in review.split(' '):
# --> 104             self.layer_0[0][word2index[w]] += 1
#     105
#     106     def get_target_for_label(self,label):
#
# IndexError: index 73686 is out of bounds for axis 0 with size 72810

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-ad0ddebea879> in <module>()
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-121-c8cfd5792831> in train(self, training_reviews, training_labels)
#     144             #       Do not use an activation function for the hidden layer,
#     145             #       but use the sigmoid activation function for the output layer.
# --> 146             update_input_layer(review)
#     147             hidden_input = np.dot(self.layer_0, self.weights_0_1)
#     148             hidden_output = hidden_input
#
# <ipython-input-90-c16a075756bb> in update_input_layer(review)
#      14     # TODO: count how many times each word is used in the given review and store the results in layer_0
#      15     for w in review.split(' '):
# ---> 16         layer_0[0][word2index[w]] += 1
#      17
#
# KeyError: 'The'

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
